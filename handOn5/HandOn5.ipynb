# %% [markdown]
# ### Import

# %%
from urllib.parse import urlparse, urljoin
from pathlib import Path
from queue import Queue, Empty
from concurrent.futures import ThreadPoolExecutor
import multiprocessing
import pickle
import requests
from bs4 import BeautifulSoup, Comment
import json

# %% [markdown]
# ### Page 29-33

# %%
class MultiThreadCrawler:
    def __init__(self, base_url, depth):
        """
        Initialize the MultiThreadCrawler with base URL and depth
        """
        self.base_url = base_url #Entry point
        extracted_url = urlparse(base_url)
        parent = extracted_url.path[:extracted_url.path.find("/") + 1]
        self.root_url = "{}://{}{}".format(extracted_url.scheme, extracted_url.netloc, parent)
        self.pool = ThreadPoolExecutor(max_workers=multiprocessing.cpu_count() - 1)
        self.to_crawl = Queue()  # Queue to store URLs to be crawled / Create a queue
        self.to_crawl.put({self.base_url: depth})  # Add the entry url to the queue
        self.stored_folder = Path(Path().absolute()).parent / "crawled/"

        if not Path(self.stored_folder).exists():
            Path.mkdir(self.stored_folder)

        # Load crawled pages if already saved
        if Path(self.stored_folder / "url_list.pickle").exists(): # Continue from the saved work or start a new one
            with open(self.stored_folder / "url_list.pickle", "rb") as f:
                self.crawled_pages = pickle.load(f)
            print(self.crawled_pages)
        else:
            self.crawled_pages = set()

    def extract_page(self, obj):
        """
        Extract content and links from a downloaded page
        """
        if obj.result():
            result, url, depth = obj.result()
            if result and result.status_code == 200:
                url_lists = self.parse_links(result.text, depth)
                self.parse_contents(url, result.text, url_lists)

    def get_page(self, url, depth):
        """
        Download a webpage
        """
        try:
            res = requests.get(url, timeout=(3, 30))
            return res, url, depth
        except requests.RequestException: #Download a webpage
            return

    def parse_links(self, html, depth):
        """
        Extract all links from the HTML content of a page
        """
        soup = BeautifulSoup(html, 'html.parser')
        links = soup.find_all('a', href=True)
        url_lists = []
        for link in links: # Find all links by extracting all the <a href> tags
            url = link['href']
            url = urljoin(self.root_url, url)
            if depth >= 0 and ".." not in url and url not in self.crawled_pages:
                print("Adding {}".format(url))
                # Enqueue the URL if it has not been visited and has not reached the depth threshold.
                self.to_crawl.put({url: depth})
                url_lists.append(url)
        return url_lists

    def parse_contents(self, url, html, url_lists):
        """
        Extract visible text and save it along with the URL and links
        """
        def tag_visible(element):
            if element.parent.name in ['style', 'script', 'head', 'title', 'meta', '[document]']:
                return False
            if isinstance(element, Comment):
                return False
            return True

        try:
            soup = BeautifulSoup(html, 'html.parser')
            texts = soup.findAll(string=True)
            visible_texts = filter(tag_visible, texts) # Get all the texts from visible tags
            title = soup.find('title').string.strip()
            text = u" ".join(t.strip() for t in visible_texts).strip()
            # Store the extracted links in a JSON format and write the JSON data to a text file.
            with open(self.stored_folder / (str(hash(url)) + '.txt'), 'w', encoding='utf-8') as f:
                json.dump({'url': url, 'title': title, 'text': text, 'url_lists': url_lists}, f, ensure_ascii=False)
        except:
            pass

    def run_scraper(self):
        """
        Continuously process the queue of URLs to scrape content
        """
        while True:
            try:
                # Get the first URL from the queue
                target = self.to_crawl.get(timeout=10) # Dequeue the first entry
                url, depth = [(k, target[k]) for k in target][0]

                # Skip if the URL has already been crawled
                if url not in self.crawled_pages: # If unprocessed
                    self.crawled_pages.add(url)

                    # Submit the task to the thread pool
                    job = self.pool.submit(self.get_page, url, depth - 1)
                    job.add_done_callback(self.extract_page)

            except Empty:
                # Save crawled pages to a file when the queue is empty
                with open(self.stored_folder / "url_list.pickle", "wb") as f:
                    pickle.dump(self.crawled_pages, f, pickle.HIGHEST_PROTOCOL)
                # The task is done when there is no remaining URL in the queue.
                with open(self.stored_folder / "url_list.pickle", "rb") as f:
                    print(pickle.load(f))
                break

            except Exception as e:
                print(e)
                continue

# %% [markdown]
# ### Page 33

# %%
if __name__ == '__main__':
    s = MultiThreadCrawler("https://cmu.ac.th/en/faculty/aboutus", 2)
    s.run_scraper()
# Out:
# Adding https://cmu.ac.th/Controls/ShareContent/
# Adding https://cmu.ac.th/course
# Adding https://mis.cmu.ac.th/TQF/TQF2/CurriculumPublicList.aspx
# Adding https://cmu.ac.th/level/bachelor
# Adding https://cmu.ac.th/level/master_bachelor
# Adding https://cmu.ac.th/level/phd
# Adding https://cmu.ac.th/Level/other
# Adding https://cmu.ac.th/Controls/ShareContent/
# Adding https://cmu.ac.th/content/F0917C78-2125-4FFD-AF68-BE9E4F5E0D36
# Adding https://cmu.ac.th/content/E13BF8C0-7C77-46BA-BEA1-56392A967AEF
# Adding https://cmu.ac.th/content/425815A0-90AB-4F39-9DA9-8D5DEA9CDBED
# Adding https://cmu.ac.th/content/D4F81742-3F7A-4197-8286-4B568129DCF1
# Adding https://cmu.ac.th/Controls/ShareContent/
# Adding https://cmu.ac.th/aboutus
# Adding https://cmu.ac.th/organization
# Adding https://cmu.ac.th/content/7A7616BC-C917-407E-8ED9-9F544D3416BA
# Adding https://cmu.ac.th/th/faculty/aboutus
# Adding https://cmu.ac.th/aboutus
# Adding https://cmu.ac.th/cn/faculty/aboutus
# Adding javascript:void(0)
# Adding javascript:__doPostBack('ctl00$wucNavBar$LinkSearch','')
# Adding https://cmu.ac.th/home
# Adding https://cmu.ac.th/th/faculty/aboutus
# Adding https://cmu.ac.th/aboutus
# Adding https://cmu.ac.th/cn/faculty/aboutus
# Adding https://cmu.ac.th/Controls/ShareContent/
# Adding https://cmu.ac.th/course
# Adding https://mis.cmu.ac.th/TQF/TQF2/CurriculumPublicList.aspx
# Adding https://cmu.ac.th/level/bachelor
# Adding https://cmu.ac.th/level/master_bachelor
# Adding https://cmu.ac.th/level/phd
# Adding https://cmu.ac.th/Level/other
# Adding https://cmu.ac.th/Controls/ShareContent/
# Adding https://cmu.ac.th/content/F0917C78-2125-4FFD-AF68-BE9E4F5E0D36
# Adding https://cmu.ac.th/content/E13BF8C0-7C77-46BA-BEA1-56392A967AEF
# Adding https://cmu.ac.th/content/425815A0-90AB-4F39-9DA9-8D5DEA9CDBED
# Adding https://cmu.ac.th/content/D4F81742-3F7A-4197-8286-4B568129DCF1
# Adding https://cmu.ac.th/Controls/ShareContent/
# Adding https://cmu.ac.th/aboutus
# Adding https://cmu.ac.th/organization
# Adding https://cmu.ac.th/content/7A7616BC-C917-407E-8ED9-9F544D3416BA
# Adding https://cmu.ac.th/Controls/ShareContent/
# Adding https://cmu.ac.th/articlegroup/8ec421a6-3c06-4de9-b42e-0fd5486e420a
# Adding https://cmu.ac.th/articlegroup/21c227c8-b12e-494b-b37b-ca8458ab863e
# Adding https://cmu.ac.th/articlegroup/02b0be9c-5700-4119-8b05-00e4efcb97e7
# Adding https://cmu.ac.th/articlegroup/19536cb6-d89a-4805-b5ab-89bee152e3f9
# Adding https://cmu.ac.th/articlegroup/c902f832-5354-4579-83da-1ec08a468e68
# Adding https://cmu.ac.th/articlegroup/35e916ed-0f06-45fe-9b09-2932cbb21780
# Adding https://cmu.ac.th/articlegroup/726e7707-60ca-497f-aff9-077a4f380b5d
# Adding https://cmu.ac.th/procurement
# Adding https://cmu.ac.th/calendar
# Adding https://cmu.ac.th/articlegroup/3c8ab7ce-8228-43bd-aa91-e48b436c81b7
# Adding https://cmu.ac.th/Controls/ShareContent/
# Adding https://cmu.ac.th/cmu/history
# Adding https://www.cmu.ac.th/th/60years
# Adding https://cmu.ac.th/cmu/resolution
# Adding https://cmu.ac.th/content/934C86C0-D272-4171-8C9E-590926DD9B66
# Adding https://cmu.ac.th/cmu/symbol
# Adding https://cmu.ac.th/cmu/aboutus
# Adding https://cmu.ac.th/content/D65CB215-9918-4D97-9F54-DCBB749E7159
# Adding https://cmu.ac.th/360/
# Adding https://cmu.ac.th/content/4EEE10D2-E793-4E55-8D67-400C510F98FE
# Adding https://council.cmu.ac.th/th/cmu-management-chart/
# Adding https://planning.oou.cmu.ac.th/?p=1970
# Adding https://council.cmu.ac.th/th/members-of-cmu-council/
# Adding https://cmu.ac.th/university/board
# Adding https://cmu.ac.th/university/head
# Adding https://cmu.ac.th/university/adminstrative_offices
# Adding https://ec.oou.cmu.ac.th/about-us/board
# Adding https://cmu.ac.th/ci/cmu-powerpoint-template/
# Adding https://m.me/cmuofficial
# Adding https://cmu.ac.th/privacy
# Adding https://cmu.ac.th/content/7F64EE14-922A-41B0-B247-E5DD81957E01
# Adding https://voc.cmu.ac.th/Choose.aspx
# Adding https://cmu.ac.th/
# Adding https://cmu.ac.th/faculty
# Adding https://cmu.ac.th/mass_communication/aboutus/head
# Adding https://cmu.ac.th/mass_communication/aboutus/head
# Adding https://cmu.ac.th/agriculture/aboutus/head
# Adding https://cmu.ac.th/agriculture/aboutus/head
# Adding https://cmu.ac.th/dentistry/aboutus/head
# Adding https://cmu.ac.th/dentistry/aboutus/head
# Adding https://cmu.ac.th/associated_medical_sciences/aboutus/head
# Adding https://cmu.ac.th/associated_medical_sciences/aboutus/head
# Adding https://cmu.ac.th/law/aboutus/head
# Adding https://cmu.ac.th/law/aboutus/head
# Adding https://cmu.ac.th/business_administration/aboutus/head
# Adding https://cmu.ac.th/business_administration/aboutus/head
# Adding https://cmu.ac.th/nursing/aboutus/head
# Adding https://cmu.ac.th/nursing/aboutus/head
# Adding https://cmu.ac.th/medicine/aboutus/head
# Adding https://cmu.ac.th/medicine/aboutus/head
# Adding https://cmu.ac.th/pharmacy/aboutus/head
# Adding https://cmu.ac.th/pharmacy/aboutus/head
# Adding https://cmu.ac.th/humanities/aboutus/head
# Adding https://cmu.ac.th/humanities/aboutus/head
# Adding https://cmu.ac.th/political_science_and_public_administration/aboutus/head
# Adding https://cmu.ac.th/political_science_and_public_administration/aboutus/head
# Adding https://cmu.ac.th/fine_arts/aboutus/head
# Adding https://cmu.ac.th/fine_arts/aboutus/head
# Adding https://cmu.ac.th/science/aboutus/head
# Adding https://cmu.ac.th/science/aboutus/head
# Adding https://cmu.ac.th/engineering/aboutus/head
# Adding https://cmu.ac.th/engineering/aboutus/head
# Adding https://cmu.ac.th/education/aboutus/head
# Adding https://cmu.ac.th/education/aboutus/head
# Adding https://cmu.ac.th/economics/aboutus/head
# Adding https://cmu.ac.th/economics/aboutus/head
# Adding https://cmu.ac.th/architecture/aboutus/head
# Adding https://cmu.ac.th/architecture/aboutus/head
# Adding https://cmu.ac.th/social_sciences/aboutus/head
# Adding https://cmu.ac.th/social_sciences/aboutus/head
# Adding https://cmu.ac.th/veterinary_medicine/aboutus/head
# Adding https://cmu.ac.th/veterinary_medicine/aboutus/head
# Adding https://cmu.ac.th/public_health/aboutus/head
# Adding https://cmu.ac.th/public_health/aboutus/head
# Adding https://cmu.ac.th/agro_industry/aboutus/head
# Adding https://cmu.ac.th/agro_industry/aboutus/head
# Adding https://cmu.ac.th/international_college_and_digital_innovation/aboutus/head
# Adding https://cmu.ac.th/international_college_and_digital_innovation/aboutus/head
# Adding https://cmu.ac.th/the_graduate_school/aboutus/head
# Adding https://cmu.ac.th/the_graduate_school/aboutus/head
# Adding https://cmu.ac.th/the_college_of_arts_media_and_technology/aboutus/head
# Adding https://cmu.ac.th/the_college_of_arts_media_and_technology/aboutus/head
# Adding https://cmu.ac.th/school_of_public_policy/aboutus/head
# Adding https://cmu.ac.th/school_of_public_policy/aboutus/head
# Adding https://cmu.ac.th/biomedical_engineering_center/aboutus/head
# Adding https://cmu.ac.th/biomedical_engineering_center/aboutus/head
# Adding https://cmu.ac.th/
# Adding https://cmu.ac.th/Content/University/CMUPhoneBook.pdf
# Adding https://cmu.ac.th/Content/University/BrochureCMU-Map2017.pdf
# Adding https://donate.cmu.ac.th
# Adding https://portal.office.com
# Adding https://mis.cmu.ac.th
# Adding https://cmubackoffice.mis.cmu.ac.th
# Adding https://cmu.ac.th/360/
# Adding https://cmu.ac.th/
# Adding https://www.facebook.com/cmuofficial/
# Adding https://www.youtube.com/@ChiangMaiUniversity
# Adding https://www.tiktok.com/@cmutiktok
# Adding https://twitter.com/cmuofficial_tw?s=09
# Adding https://www.instagram.com/cmuofficial.ig/
# Adding https://voc.cmu.ac.th/Choose.aspx
# Adding https://cmu.ac.th/#top
# Adding https://cmu.ac.th/#top
# Adding https://m.me/cmuofficial
# Adding https://cmu.ac.th/CurriculumLecturerPublicList.aspx
# Adding https://cmu.ac.th/60years
# Adding https://cmu.ac.th/en/60years
# Adding https://cmu.ac.th/cn/60years
# Adding javascript:__doPostBack('ctl00$wucNavBar60Year$LinkSearch','')
# Adding https://cmu.ac.th/th/60years/
# Adding https://cmu.ac.th/Controls/Home/
# Adding https://cmu.ac.th/th/60years/content/0b7c9ffe-7d23-4f96-90da-d8bfaacf526c/
# Adding https://cmu.ac.th/th/60years/history/
# Adding https://cmu.ac.th/ci/
# Adding https://cmu.ac.th/Controls/Home/
# Adding https://cmu.ac.th/th/60years/articlegroup/059f5f5d-b062-4370-83ee-fbc7d0a68e00/
# Adding https://cmu.ac.th/th/60years/articlegroup/35e916ed-0f06-45fe-9b09-2932cbb21780/
# Adding https://cmu.ac.th/Controls/Home/
# Adding https://cmu.ac.th/th/60years/articlegroup/1f1fbbd0-999c-4e40-bb9f-f73e4776a185/
# Adding https://cmu.ac.th/th/60years/vdo/
# Adding https://cmu.ac.th/th/60years/calendar/
# Adding https://shop.cmu.ac.th
# Adding https://cmu.ac.th/th/60years/articlegroup/059f5f5d-b062-4370-83ee-fbc7d0a68e00
# Adding https://cmu.ac.th/th/60years/article/a0f45a18-bdc2-47f4-84f7-1573b3db568e
# Adding https://cmu.ac.th/th/60years/article/a0f45a18-bdc2-47f4-84f7-1573b3db568e
# Adding https://cmu.ac.th/th/60years/article/7cfabd7c-8d84-44c2-a4e7-ee1ac313a024
# Adding https://cmu.ac.th/th/60years/article/7cfabd7c-8d84-44c2-a4e7-ee1ac313a024
# Adding https://cmu.ac.th/th/60years/article/73a341d9-492e-4e60-9e73-8233a879732d
# Adding https://cmu.ac.th/th/60years/article/73a341d9-492e-4e60-9e73-8233a879732d
# Adding https://cmu.ac.th/SDGs/1
# Adding https://cmu.ac.th/SDGs/4
# Adding https://cmu.ac.th/SDGs/8
# Adding https://cmu.ac.th/SDGs/10
# Adding https://cmu.ac.th/SDGs/11
# Adding https://cmu.ac.th/SDGs/16
# Adding https://cmu.ac.th/th/60years/article/1d872472-2c06-42c3-88be-a865c888f60d
# Adding https://cmu.ac.th/th/60years/article/1d872472-2c06-42c3-88be-a865c888f60d
# Adding https://cmu.ac.th/SDGs/7
# Adding https://cmu.ac.th/SDGs/9
# Adding https://cmu.ac.th/SDGs/17
# Adding https://cmu.ac.th/th/60years/article/ec2f9b9d-306c-4f55-8251-820407e389f2
# Adding https://cmu.ac.th/th/60years/article/ec2f9b9d-306c-4f55-8251-820407e389f2
# Adding https://cmu.ac.th/SDGs/4
# Adding https://cmu.ac.th/SDGs/9
# Adding https://cmu.ac.th/SDGs/17
# Adding https://cmu.ac.th/th/60years/article/2c65a55f-c374-49c0-8de5-057f42154144
# Adding https://cmu.ac.th/th/60years/article/2c65a55f-c374-49c0-8de5-057f42154144
# Adding https://cmu.ac.th/SDGs/4
# Adding https://cmu.ac.th/SDGs/11
# Adding https://cmu.ac.th/SDGs/17
# Adding https://cmu.ac.th/th/60years/article/e3223416-d1de-4585-9749-ce1bdedcbc08
# Adding https://cmu.ac.th/th/60years/article/e3223416-d1de-4585-9749-ce1bdedcbc08
# Adding https://cmu.ac.th/th/60years/article/c3f272d7-2c38-44e6-88ca-bf19596f6d40
# Adding https://cmu.ac.th/th/60years/article/c3f272d7-2c38-44e6-88ca-bf19596f6d40
# Adding https://cmu.ac.th/SDGs/4
# Adding https://cmu.ac.th/SDGs/11
# Adding https://cmu.ac.th/SDGs/17
# Adding https://cmu.ac.th/th/60years/article/d670c161-e1c6-4a08-a70c-c99241a00ad5
# Adding https://cmu.ac.th/th/60years/article/d670c161-e1c6-4a08-a70c-c99241a00ad5
# Adding https://cmu.ac.th/th/60years/article/7b2ad503-de70-4bb7-bcaf-97fc442ce935
# Adding https://cmu.ac.th/th/60years/article/7b2ad503-de70-4bb7-bcaf-97fc442ce935
# Adding https://cmu.ac.th/th/60years/article/facfffc7-68d0-454b-89a3-e221d769ee58
# Adding https://cmu.ac.th/th/60years/article/facfffc7-68d0-454b-89a3-e221d769ee58
# Adding https://cmu.ac.th/SDGs/3
# Adding https://cmu.ac.th/SDGs/9
# Adding https://cmu.ac.th/SDGs/17
# Adding https://cmu.ac.th/th/60years/article/84a6fc60-f929-4bac-b0e5-f68a3582cd1e
# Adding https://cmu.ac.th/th/60years/article/84a6fc60-f929-4bac-b0e5-f68a3582cd1e
# Adding https://cmu.ac.th/th/60years/article/4262292f-f7ef-4818-9462-72c315548c04
# Adding https://cmu.ac.th/th/60years/article/4262292f-f7ef-4818-9462-72c315548c04
# Adding https://cmu.ac.th/SDGs/11
# Adding https://cmu.ac.th/th/60years/article/b02c6ed8-47ad-4834-bd09-109755b32a4c
# Adding https://cmu.ac.th/th/60years/article/b02c6ed8-47ad-4834-bd09-109755b32a4c
# Adding https://cmu.ac.th/SDGs/3
# Adding https://cmu.ac.th/SDGs/17
# Adding https://cmu.ac.th/th/60years/article/d22c1503-4876-4c8c-9e54-7728c7d4975f
# Adding https://cmu.ac.th/th/60years/article/d22c1503-4876-4c8c-9e54-7728c7d4975f
# Adding https://cmu.ac.th/th/60years/article/99b93339-c419-443c-a6cf-374bef160703
# Adding https://cmu.ac.th/th/60years/article/99b93339-c419-443c-a6cf-374bef160703
# Adding https://cmu.ac.th/SDGs/11
# Adding https://cmu.ac.th/th/60years/article/01c417df-3707-4d5c-bfcc-eda801833476
# Adding https://cmu.ac.th/th/60years/article/01c417df-3707-4d5c-bfcc-eda801833476
# Adding https://cmu.ac.th/th/60years/article/eae624c8-67b6-495a-9c9a-89422b9de951
# Adding https://cmu.ac.th/th/60years/article/eae624c8-67b6-495a-9c9a-89422b9de951
# Adding https://cmu.ac.th/th/60years/article/a1e912bb-ce6b-48de-8222-f8cd02b8540b
# Adding https://cmu.ac.th/th/60years/article/a1e912bb-ce6b-48de-8222-f8cd02b8540b
# Adding https://cmu.ac.th/th/60years/article/7d7325f9-0019-4d81-826a-7abec3c0f6a2
# Adding https://cmu.ac.th/th/60years/article/7d7325f9-0019-4d81-826a-7abec3c0f6a2
# Adding https://cmu.ac.th/th/60years/article/3d4ad6ea-0d1d-433d-9a3b-cb358378b771
# Adding https://cmu.ac.th/th/60years/article/3d4ad6ea-0d1d-433d-9a3b-cb358378b771
# Adding https://cmu.ac.th/th/60years/article/9ad63318-8602-4b8d-98b6-bd051b1ef1dc
# Adding https://cmu.ac.th/th/60years/article/9ad63318-8602-4b8d-98b6-bd051b1ef1dc
# Adding https://cmu.ac.th/th/60years/article/0e3b896b-b1e8-489f-92fc-8a4454f48df9
# Adding https://cmu.ac.th/th/60years/article/0e3b896b-b1e8-489f-92fc-8a4454f48df9
# Adding https://cmu.ac.th/th/60years/article/0902dd35-0fd2-4f67-8ee7-0b47645b795c
# Adding https://cmu.ac.th/th/60years/article/0902dd35-0fd2-4f67-8ee7-0b47645b795c
# Adding https://cmu.ac.th/th/60years/article/48c27e39-07cf-4842-8d2b-03a07b459395
# Adding https://cmu.ac.th/th/60years/article/48c27e39-07cf-4842-8d2b-03a07b459395
# Adding https://cmu.ac.th/SDGs/3
# Adding https://cmu.ac.th/SDGs/17
# Adding https://cmu.ac.th/th/60years/article/177883b5-daaf-4ded-bcc3-bc0721bd857c
# Adding https://cmu.ac.th/th/60years/article/177883b5-daaf-4ded-bcc3-bc0721bd857c
# Adding https://cmu.ac.th/SDGs/3
# Adding https://cmu.ac.th/SDGs/17
# Adding https://cmu.ac.th/th/60years/article/f728b4fa-9348-4c5c-80a1-1c6af5e53071
# Adding https://cmu.ac.th/th/60years/article/f728b4fa-9348-4c5c-80a1-1c6af5e53071
# Adding https://cmu.ac.th/SDGs/3
# Adding https://cmu.ac.th/SDGs/17
# Adding https://cmu.ac.th/th/60years/article/860af491-5555-49d0-81c2-ec290269c90d
# Adding https://cmu.ac.th/th/60years/article/860af491-5555-49d0-81c2-ec290269c90d
# Adding https://cmu.ac.th/th/60years/article/0fe86d7a-7ce0-4b9d-8fff-0caa037d44b9
# Adding https://cmu.ac.th/th/60years/article/0fe86d7a-7ce0-4b9d-8fff-0caa037d44b9
# Adding https://cmu.ac.th/SDGs/17
# Adding https://cmu.ac.th/th/60years/article/142950ad-3870-4d85-a785-8f3bb3659214
# Adding https://cmu.ac.th/th/60years/article/142950ad-3870-4d85-a785-8f3bb3659214
# Adding javascript:__doPostBack('ctl00$cphPageContent$wucArticleGroup1$lbtnNext','')
# Adding javascript:__doPostBack('ctl00$cphPageContent$wucArticleGroup1$lbtnLast','')
# Adding https://cmu.ac.th/th/60years/articlegroup/1f1fbbd0-999c-4e40-bb9f-f73e4776a185
# Adding https://cmu.ac.th/th/60years/article/73a341d9-492e-4e60-9e73-8233a879732d
# Adding https://cmu.ac.th/th/60years/article/73a341d9-492e-4e60-9e73-8233a879732d
# Adding https://cmu.ac.th/SDGs/1
# Adding https://cmu.ac.th/SDGs/4
# Adding https://cmu.ac.th/SDGs/8
# Adding https://cmu.ac.th/SDGs/10
# Adding https://cmu.ac.th/SDGs/11
# Adding https://cmu.ac.th/SDGs/16
# Adding https://cmu.ac.th/th/60years/article/01c417df-3707-4d5c-bfcc-eda801833476
# Adding https://cmu.ac.th/th/60years/article/01c417df-3707-4d5c-bfcc-eda801833476
# Adding https://cmu.ac.th/th/60years/article/4b2d70e9-023f-42d1-baf2-d032115eae2a
# Adding https://cmu.ac.th/th/60years/article/4b2d70e9-023f-42d1-baf2-d032115eae2a
# Adding https://cmu.ac.th/th/60years/article/22fa2817-3177-41dc-a814-220ff37c5fff
# Adding https://cmu.ac.th/th/60years/article/22fa2817-3177-41dc-a814-220ff37c5fff
# Adding https://cmu.ac.th/th/60years/article/2a8439a8-d2b9-464c-8ba1-068d1332d465
# Adding https://cmu.ac.th/th/60years/article/2a8439a8-d2b9-464c-8ba1-068d1332d465
# Adding https://cmu.ac.th/th/60years/article/581955db-9125-452f-9b73-5ef2a16c0697
# Adding https://cmu.ac.th/th/60years/article/581955db-9125-452f-9b73-5ef2a16c0697
# Adding https://cmu.ac.th/th/60years/article/754898dd-02cd-490b-bf14-e6823c1975a4
# Adding https://cmu.ac.th/th/60years/article/754898dd-02cd-490b-bf14-e6823c1975a4
# Adding https://cmu.ac.th/th/60years/article/86128b77-5844-41dd-990f-6ec842cf44c3
# Adding https://cmu.ac.th/th/60years/article/86128b77-5844-41dd-990f-6ec842cf44c3
# Adding https://cmu.ac.th/th/60years/article/ecdf8ffa-5c0b-4a5c-ad59-56f73fc30693
# Adding https://cmu.ac.th/th/60years/article/ecdf8ffa-5c0b-4a5c-ad59-56f73fc30693
# Adding https://cmu.ac.th/th/60years/article/8c2e92f4-4b07-4234-a440-d9d994096404
# Adding https://cmu.ac.th/th/60years/article/8c2e92f4-4b07-4234-a440-d9d994096404
# Adding https://cmu.ac.th/choose.aspx?lang=en
# Adding https://cmu.ac.th/choose.aspx?lang=th
# Adding https://cmu.ac.th/OAuthLogin.aspx
# Adding https://itsc.cmu.ac.th/
# Adding https://cmu.ac.th/?p=3788
# Adding https://cmu.ac.th/#content
# Adding https://planning.oou.cmu.ac.th/
# Adding https://planning.oou.cmu.ac.th/
# Adding https://planning.oou.cmu.ac.th/?lang=th
# Adding https://planning.oou.cmu.ac.th/?page_id=30
# Adding https://planning.oou.cmu.ac.th/?page_id=44
# Adding https://planning.oou.cmu.ac.th/?page_id=32
# Adding https://planning.oou.cmu.ac.th/?page_id=2903
# Adding https://planning.oou.cmu.ac.th/?page_id=4013
# Adding https://planning.oou.cmu.ac.th/?page_id=4029
# Adding https://planning.oou.cmu.ac.th/?cat=34
# Adding https://planning.oou.cmu.ac.th/?page_id=3475
# Adding https://www.facebook.com/PlanningCMU/photos/?tab=albums
# Adding https://planning.oou.cmu.ac.th/?page_id=4274
# Adding https://e-planning.mis.cmu.ac.th
# Adding http://www.sys.oop.cmu.ac.th/
# Adding https://planning.oou.cmu.ac.th/?cat=38
# Adding https://planning.oou.cmu.ac.th/?cat=36
# Adding https://planning.oou.cmu.ac.th/?page_id=3658
# Adding https://planning.oou.cmu.ac.th/?cat=96
# Adding https://planning.oou.cmu.ac.th/?cat=48
# Adding https://planning.oou.cmu.ac.th/?cat=24
# Adding https://planning.oou.cmu.ac.th/?page_id=994
# Adding https://planning.oou.cmu.ac.th/?page_id=135
# Adding https://planning.oou.cmu.ac.th/?page_id=621
# Adding https://planning.oou.cmu.ac.th/?page_id=3875
# Adding https://planning.oou.cmu.ac.th/wp-admin
# Adding https://planning.oou.cmu.ac.th/?page_id=3547
# Adding https://planning.oou.cmu.ac.th/?lang=th
# Adding https://planning.oou.cmu.ac.th/?page_id=30
# Adding https://planning.oou.cmu.ac.th/?page_id=44
# Adding https://planning.oou.cmu.ac.th/?page_id=32
# Adding https://planning.oou.cmu.ac.th/?page_id=2903
# Adding https://planning.oou.cmu.ac.th/?page_id=4013
# Adding https://planning.oou.cmu.ac.th/?page_id=4029
# Adding https://planning.oou.cmu.ac.th/?cat=34
# Adding https://planning.oou.cmu.ac.th/?page_id=3475
# Adding https://www.facebook.com/PlanningCMU/photos/?tab=albums
# Adding https://planning.oou.cmu.ac.th/?page_id=4274
# Adding https://e-planning.mis.cmu.ac.th
# Adding http://www.sys.oop.cmu.ac.th/
# Adding https://planning.oou.cmu.ac.th/?cat=38
# Adding https://planning.oou.cmu.ac.th/?cat=36
# Adding https://planning.oou.cmu.ac.th/?page_id=3658
# Adding https://planning.oou.cmu.ac.th/?cat=96
# Adding https://planning.oou.cmu.ac.th/?cat=48
# Adding https://planning.oou.cmu.ac.th/?cat=24
# Adding https://planning.oou.cmu.ac.th/?page_id=994
# Adding https://planning.oou.cmu.ac.th/?page_id=135
# Adding https://planning.oou.cmu.ac.th/?page_id=621
# Adding https://planning.oou.cmu.ac.th/?page_id=3875
# Adding https://planning.oou.cmu.ac.th/wp-admin
# Adding https://planning.oou.cmu.ac.th/?page_id=3547
# Adding https://planning.oou.cmu.ac.th/?cat=52
# Adding https://planning.oou.cmu.ac.th/?cat=24
# Adding https://planning.oou.cmu.ac.th/?cat=128
# Adding https://planning.oou.cmu.ac.th/?cat=50
# Adding https://planning.oou.cmu.ac.th/wp-content/uploads/2022/05/2022-05-25_16-07-06_-13--2.pdf
# Adding https://planning.oou.cmu.ac.th/wp-content/uploads/2017/10/2022-02-08_16-57-14_2020-07-10-07-56-36-12-100763.pdf
# Adding https://planning.oou.cmu.ac.th/wp-content/uploads/2017/10/2017-10-02_07-10-12_-12-1760.pdf
# Adding https://planning.oou.cmu.ac.th/wp-content/uploads/2019/06/2019-06-20_07-45-51_62-65-.pdf
# Adding https://planning.oou.cmu.ac.th/wp-content/uploads/2017/10/2019-06-21_02-59-18_o10-62.pdf
# Adding https://planning.oou.cmu.ac.th/wp-content/uploads/2017/10/2019-06-21_03-00-44_o18--62.pdf
# Adding https://planning.oou.cmu.ac.th/
# Adding https://facebook.com/planningCMU
# Adding https://facebook.com/planningCMU
# Adding https://planning.oou.cmu.ac.th/?page_id=135
# Adding https://planning.oou.cmu.ac.th/?page_id=135
# Adding https://planning.oou.cmu.ac.th/?page_id=621
# Adding https://planning.oou.cmu.ac.th/?page_id=621
# Adding https://voc.cmu.ac.th/VOC1.aspx?OID=75
# Adding https://voc.cmu.ac.th/VOC1.aspx?OID=75
# Adding https://e-planning.mis.cmu.ac.th
# Adding https://www.sys.oop.cmu.ac.th/pmaservice/signups/login
# Adding https://www.sys.oop.cmu.ac.th
# Adding http://planningcloud.oop.cmu.ac.th
# Adding https://mis.cmu.ac.th/cmumis/
# Adding https://mis.cmu.ac.th/cmumis/
# Adding https://mis.cmu.ac.th/cmumis/
# Adding https://www.sys.oop.cmu.ac.th/meetingroom/signups/login
# Adding https://www.sys.oop.cmu.ac.th/meetingroom/signups/login
# Adding https://www.sys.oop.cmu.ac.th/meetingroom/signups/login
# Adding https://planning.oou.cmu.ac.th/wp-content/uploads/2023/04/2023-04-04_09-25-47_--.pdf
# Adding https://planning.oou.cmu.ac.th/wp-content/uploads/2023/04/2023-04-04_09-25-47_--.pdf
# Adding https://planning.oou.cmu.ac.th/wp-content/uploads/2023/04/2023-04-04_09-25-47_--.pdf
# Adding https://e-planning.mis.cmu.ac.th/
# Adding https://www.sys.oop.cmu.ac.th/pmaservice/signups/login
# Adding http://planningcloud.oop.cmu.ac.th/
# Adding https://council.cmu.ac.th/th/
# Adding https://council.cmu.ac.th/th/boardchairman/
# Adding https://council.cmu.ac.th/th/council-authority/
# Adding https://council.cmu.ac.th
# Adding https://council.cmu.ac.th/th/cmu-council-representative/
# Adding https://council.cmu.ac.th/th/history-of-council-office/
# Adding https://council.cmu.ac.th/th/office_vision_authorize/
# Adding https://council.cmu.ac.th/th/office-org-chart/
# Adding https://council.cmu.ac.th/th/council-office-staff/
# Adding https://council.cmu.ac.th/th/virtue-office/
# Adding https://cmulaw.cmu.ac.th/
# Adding https://council.cmu.ac.th/th/ita/
# Adding https://council.cmu.ac.th/en
# Adding https://council.cmu.ac.th/th/
# Adding https://council.cmu.ac.th/th/
# Adding https://council.cmu.ac.th/th/boardchairman/
# Adding https://council.cmu.ac.th/th/council-authority/
# Adding https://council.cmu.ac.th/th/cmu-council-representative/
# Adding https://council.cmu.ac.th/th/history-of-council-office/
# Adding https://council.cmu.ac.th/th/office_vision_authorize/
# Adding https://council.cmu.ac.th/th/office-org-chart/
# Adding https://council.cmu.ac.th/th/council-office-staff/
# Adding https://council.cmu.ac.th/th/virtue-office/
# Adding https://cmulaw.cmu.ac.th/
# Adding https://council.cmu.ac.th/th/ita/
# Adding https://council.cmu.ac.th/co-static/other/2567-11-01_cmu-management-chart.pdf
# Adding https://council.cmu.ac.th/co-static/other/2567-11-01_cmu-management-chart.pdf
# Adding https://council.cmu.ac.th/th/boardchairman/
# Adding https://council.cmu.ac.th/th/council-member/
# Adding https://council.cmu.ac.th/th/council-authority/
# Adding https://council.cmu.ac.th/th/cmu-council-representative/
# Adding https://council.cmu.ac.th/th/history-of-council-office/
# Adding https://council.cmu.ac.th/th/office_vision_authorize/
# Adding https://council.cmu.ac.th/th/office-org-chart/
# Adding https://council.cmu.ac.th/th/council-office-staff/
# Adding https://council.cmu.ac.th/th/ita/
# Adding https://www.cmu.ac.th/th/faculty/aboutus
# Adding https://www.cmu.ac.th/th/organization
# Adding https://council.cmu.ac.th/th/cmu-pex/
# Adding https://rm.mis.cmu.ac.th/
# Adding https://council.cmu.ac.th/th/useful-hint/
# Adding https://e-council.cmu.ac.th/
# Adding https://docs.council.cmu.ac.th/
# Adding https://emeeting.cmu.ac.th/
# Adding https://oauth.cmu.ac.th/v1/Authorize.aspx?response_type=code&client_id=KhhsJKW9uReaAfhGY2jqtWfR5bN95P6QtmU7EtAx&redirect_uri=https://council.cmu.ac.th/search-for-conclusion/oauth_token.php&scope=basic
# Adding https://council.cmu.ac.th/th/president-evaluation/
# Adding https://council.cmu.ac.th/th/performance-evaluation/
# Adding https://council.cmu.ac.th/th/knowledge-management/
# Adding https://www.facebook.com/cmu.council
# Adding https://council.cmu.ac.th/th/map/
# Adding http://www.cmu.ac.th/
# Adding https://mail.cmu.ac.th
# Adding https://portal.cmu.ac.th/
# Adding https://cmulaw.cmu.ac.th/
# Adding https://e-council.cmu.ac.th/
# Adding https://docs.council.cmu.ac.th/
# Adding https://edoc.cmu.ac.th/
# Adding https://emeeting.cmu.ac.th/
# Adding https://oauth.cmu.ac.th/v1/Authorize.aspx?response_type=code&client_id=KhhsJKW9uReaAfhGY2jqtWfR5bN95P6QtmU7EtAx&redirect_uri=https://council.cmu.ac.th/search-for-conclusion/oauth_token.php&scope=basic
# Adding https://rm.mis.cmu.ac.th/
# Adding https://mail.cmu.ac.th/
# Adding https://council.cmu.ac.th/th/knowledge-management/
# Adding https://council.cmu.ac.th/co-static/council_member/ratchakitcha/2568-01-02_7-members.pdf
# Adding https://council.cmu.ac.th/co-static/council_member/ratchakitcha/2567-09-27_chairman.pdf
# Adding https://council.cmu.ac.th/co-static/council_member/promotion-committee/2567-08-30_chairman.pdf
# Adding https://council.cmu.ac.th/co-static/council_member/ratchakitcha/2567-06-06_8-members.pdf
# Adding https://cmu.ac.th/ci
# Adding https://cmu.ac.th/ci/intro
# Adding https://www.cmu.ac.th
# Adding https://cmu.ac.th/ci/login-page
# Adding https://cmu.ac.th/ci/intro
# Adding https://www.cmu.ac.th
# Adding https://cmu.ac.th/ci/login-page
# Adding https://mis.cmu.ac.th/tqf/coursepublic.aspx
# Adding https://sis.cmu.ac.th
# Adding https://mis.cmu.ac.th/CMUBuildings/
# Adding https://mis.cmu.ac.th/publication
# Adding https://emeeting.cmu.ac.th
# Adding https://antivirus.cmu.ac.th
# Adding https://hr.mis.cmu.ac.th
# Adding https://emeeting.cmu.ac.th
# Adding https://cmu.ac.th/#slide_show_mis
# Adding https://cmu.ac.th/#slide_show_mis
# Adding https://cmu.ac.th/Identity/login.aspx
# Adding https://cmu.ac.th/th/faculty/course
# Adding https://cmu.ac.th/th/faculty/level/bachelor
# Adding https://cmu.ac.th/th/faculty/level/master_bachelor
# Adding https://cmu.ac.th/th/faculty/level/phd
# Adding https://cmu.ac.th/th/faculty/Level/other
# Adding https://cmu.ac.th/th/content/F0917C78-2125-4FFD-AF68-BE9E4F5E0D36
# Adding https://cmu.ac.th/th/content/E13BF8C0-7C77-46BA-BEA1-56392A967AEF
# Adding https://cmu.ac.th/th/content/425815A0-90AB-4F39-9DA9-8D5DEA9CDBED
# Adding https://cmu.ac.th/th/content/D4F81742-3F7A-4197-8286-4B568129DCF1
# Adding https://cmu.ac.th/th/organization
# Adding https://cmu.ac.th/th/content/7A7616BC-C917-407E-8ED9-9F544D3416BA
# Adding https://cmu.ac.th/th/home
# Adding https://cmu.ac.th/en/home
# Adding https://cmu.ac.th/cn/home
# Adding https://cmu.ac.th/th/home
# Adding https://cmu.ac.th/th/home
# Adding https://cmu.ac.th/en/home
# Adding https://cmu.ac.th/cn/home
# Adding https://cmu.ac.th/th/faculty/course
# Adding https://cmu.ac.th/th/faculty/level/bachelor
# Adding https://cmu.ac.th/th/faculty/level/master_bachelor
# Adding https://cmu.ac.th/th/faculty/level/phd
# Adding https://cmu.ac.th/th/faculty/Level/other
# Adding https://cmu.ac.th/th/content/F0917C78-2125-4FFD-AF68-BE9E4F5E0D36
# Adding https://cmu.ac.th/th/content/E13BF8C0-7C77-46BA-BEA1-56392A967AEF
# Adding https://cmu.ac.th/th/content/425815A0-90AB-4F39-9DA9-8D5DEA9CDBED
# Adding https://cmu.ac.th/th/content/D4F81742-3F7A-4197-8286-4B568129DCF1
# Adding https://cmu.ac.th/th/organization
# Adding https://cmu.ac.th/th/content/7A7616BC-C917-407E-8ED9-9F544D3416BA
# Adding https://cmu.ac.th/th/articlegroup/8ec421a6-3c06-4de9-b42e-0fd5486e420a
# Adding https://cmu.ac.th/th/articlegroup/21c227c8-b12e-494b-b37b-ca8458ab863e
# Adding https://cmu.ac.th/th/articlegroup/02b0be9c-5700-4119-8b05-00e4efcb97e7
# Adding https://cmu.ac.th/th/articlegroup/19536cb6-d89a-4805-b5ab-89bee152e3f9
# Adding https://cmu.ac.th/th/articlegroup/c902f832-5354-4579-83da-1ec08a468e68
# Adding https://cmu.ac.th/th/articlegroup/35e916ed-0f06-45fe-9b09-2932cbb21780
# Adding https://cmu.ac.th/th/articlegroup/726e7707-60ca-497f-aff9-077a4f380b5d
# Adding https://cmu.ac.th/th/procurement
# Adding https://cmu.ac.th/th/calendar
# Adding https://cmu.ac.th/th/articlegroup/3c8ab7ce-8228-43bd-aa91-e48b436c81b7
# Adding https://cmu.ac.th/th/cmu/history
# Adding https://cmu.ac.th/th/cmu/resolution
# Adding https://cmu.ac.th/th/content/934C86C0-D272-4171-8C9E-590926DD9B66
# Adding https://cmu.ac.th/th/cmu/symbol
# Adding https://cmu.ac.th/th/cmu/aboutus
# Adding https://cmu.ac.th/th/content/D65CB215-9918-4D97-9F54-DCBB749E7159
# Adding https://cmu.ac.th/th/content/4EEE10D2-E793-4E55-8D67-400C510F98FE
# Adding https://cmu.ac.th/th/university/board
# Adding https://cmu.ac.th/th/university/head
# Adding https://cmu.ac.th/th/university/adminstrative_offices
# Adding https://cmu.ac.th/th/privacy
# Adding https://cmu.ac.th/th/content/7F64EE14-922A-41B0-B247-E5DD81957E01
# Adding https://shop.cmu.ac.th/
# Adding https://itas.nacc.go.th/go/eit/bvwzh7
# Adding https://policy13.cmu.ac.th
# Adding https://cmu.ac.th/#slider6
# Adding https://cmu.ac.th/#slider6
# Adding https://cmu.ac.th/th/60years
# Adding https://cmu.ac.th/th/university/servicesgroup/c91c4ec5-4fa5-4813-936c-7b250c008e01
# Adding https://cmu.ac.th/th/university/servicesgroup/2b036c23-3250-4c22-a11c-c3294bc57d83
# Adding https://cmu.ac.th/th/university/servicesgroup/26ce5302-7f49-4c1e-aa73-bada6e7c05ec
# Adding https://cmu.ac.th/th/university/servicesgroup/9e73cb20-c2f9-4586-a3c5-c7a433e32300
# Adding https://cmu.ac.th/th/content/D7ABB770-4C2B-41EE-825E-720939F6DFD4
# Adding https://cmu.ac.th/th/content/40FD1693-9224-4935-ADE1-34711713C034
# Adding http://finance.oop.cmu.ac.th/?q=th/tuition_fee_announcement
# Adding https://cmu.ac.th/th/university/servicesgroup/c91c4ec5-4fa5-4813-936c-7b250c008e01
# Adding https://cmu.ac.th/th/university/servicesgroup/2b036c23-3250-4c22-a11c-c3294bc57d83
# Adding https://cmu.ac.th/th/university/servicesgroup/26ce5302-7f49-4c1e-aa73-bada6e7c05ec
# Adding https://cmu.ac.th/th/university/servicesgroup/9e73cb20-c2f9-4586-a3c5-c7a433e32300
# Adding https://cmu.ac.th/th/content/D7ABB770-4C2B-41EE-825E-720939F6DFD4
# Adding https://cmu.ac.th/th/content/40FD1693-9224-4935-ADE1-34711713C034
# Adding http://finance.oop.cmu.ac.th/?q=th/tuition_fee_announcement
# Adding https://cmu.ac.th/th/article/d1855038-7bf5-428c-8b4a-5c37a0ced05f
# Adding https://cmu.ac.th/th/article/a0f45a18-bdc2-47f4-84f7-1573b3db568e
# Adding https://cmu.ac.th/th/article/a0f45a18-bdc2-47f4-84f7-1573b3db568e
# Adding https://cmu.ac.th/th/article/743ec22a-683a-4b72-8746-4d5b622d552d
# Adding https://cmu.ac.th/th/article/743ec22a-683a-4b72-8746-4d5b622d552d
# Adding https://cmu.ac.th/th/article/586294a7-d4ea-42f6-b306-d92031119f80
# Adding https://cmu.ac.th/th/article/586294a7-d4ea-42f6-b306-d92031119f80
# Adding https://cmu.ac.th/th/article/d10e426f-cc15-47d7-9bf3-6bf8626447c2
# Adding https://cmu.ac.th/th/article/d10e426f-cc15-47d7-9bf3-6bf8626447c2
# Adding https://cmu.ac.th/th/article/04a2e829-06db-409c-97dd-fe20f2b81988
# Adding https://sdgs.cmu.ac.th
# Adding https://www.cmu.ac.th/360/
# Adding https://cmu.ac.th/th/cmu/history/timeline
# Adding https://firstyear.oou.cmu.ac.th
# Adding https://firstyear.oou.cmu.ac.th
# Adding https://cmu.ac.th/th/content/D7ABB770-4C2B-41EE-825E-720939F6DFD4
# Adding https://cmu.ac.th/th/content/D7ABB770-4C2B-41EE-825E-720939F6DFD4
# Adding https://cmu.ac.th/th/content/2DF77927-C8F6-49DC-B8C8-93702EA2AC65
# Adding https://cmu.ac.th/th/content/2DF77927-C8F6-49DC-B8C8-93702EA2AC65
# Adding http://library.cmu.ac.th/digital
# Adding http://library.cmu.ac.th/digital
# Adding https://cmu.ac.th/th/cmu/channelplus
# Adding https://cmu.ac.th/th/cmu/channelplus
# Adding https://cmu.ac.th/th/content/40FD1693-9224-4935-ADE1-34711713C034
# Adding https://cmu.ac.th/th/content/40FD1693-9224-4935-ADE1-34711713C034
# Adding https://cmu.ac.th/th/calendar
# Adding https://cmu.ac.th/th/calendar
# Adding https://itsc.cmu.ac.th/th/page/ITLife
# Adding https://itsc.cmu.ac.th/th/page/ITLife
# Adding https://cmu.ac.th/th/faculty/mass_communication/aboutus
# Adding https://cmu.ac.th/th/faculty/agriculture/aboutus
# Adding https://cmu.ac.th/th/faculty/dentistry/aboutus
# Adding https://cmu.ac.th/th/faculty/associated_medical_sciences/aboutus
# Adding https://cmu.ac.th/th/faculty/law/aboutus
# Adding https://cmu.ac.th/th/faculty/business_administration/aboutus
# Adding https://cmu.ac.th/th/faculty/nursing/aboutus
# Adding https://cmu.ac.th/th/faculty/medicine/aboutus
# Adding https://cmu.ac.th/th/faculty/pharmacy/aboutus
# Adding https://cmu.ac.th/th/faculty/humanities/aboutus
# Adding https://cmu.ac.th/th/faculty/political_science_and_public_administration/aboutus
# Adding https://cmu.ac.th/th/faculty/fine_arts/aboutus
# Adding https://cmu.ac.th/th/faculty/science/aboutus
# Adding https://cmu.ac.th/th/faculty/engineering/aboutus
# Adding https://cmu.ac.th/th/faculty/education/aboutus
# Adding https://cmu.ac.th/th/faculty/economics/aboutus
# Adding https://cmu.ac.th/th/faculty/architecture/aboutus
# Adding https://cmu.ac.th/th/faculty/social_sciences/aboutus
# Adding https://cmu.ac.th/th/faculty/veterinary_medicine/aboutus
# Adding https://cmu.ac.th/th/faculty/public_health/aboutus
# Adding https://cmu.ac.th/th/faculty/agro_industry/aboutus
# Adding https://cmu.ac.th/th/faculty/international_college_and_digital_innovation/aboutus
# Adding https://cmu.ac.th/th/faculty/the_graduate_school/aboutus
# Adding https://cmu.ac.th/th/faculty/the_college_of_arts_media_and_technology/aboutus
# Adding https://cmu.ac.th/th/faculty/school_of_public_policy/aboutus
# Adding https://cmu.ac.th/th/faculty/biomedical_engineering_center/aboutus
# Adding https://cmu.ac.th/#tab1
# Adding https://cmu.ac.th/#tab2
# Adding https://cmu.ac.th/#tab3
# Adding https://cmu.ac.th/#tab4
# Adding https://cmu.ac.th/#tab5
# Adding https://cmu.ac.th/#tab6
# Adding https://cmu.ac.th/th/articlegroup/21c227c8-b12e-494b-b37b-ca8458ab863e
# Adding https://cmu.ac.th/th/article/d1855038-7bf5-428c-8b4a-5c37a0ced05f
# Adding https://cmu.ac.th/th/article/d1855038-7bf5-428c-8b4a-5c37a0ced05f
# Adding https://cmu.ac.th/th/article/a0f45a18-bdc2-47f4-84f7-1573b3db568e
# Adding https://cmu.ac.th/th/article/a0f45a18-bdc2-47f4-84f7-1573b3db568e
# Adding https://cmu.ac.th/th/article/f8dc9a3c-fb07-49e4-add7-76547e8966aa
# Adding https://cmu.ac.th/th/article/f8dc9a3c-fb07-49e4-add7-76547e8966aa
# Adding https://cmu.ac.th/th/SDGs/4
# Adding https://cmu.ac.th/th/article/f0fd1a12-bbbb-4113-aaa9-546acb5e286c
# Adding https://cmu.ac.th/th/article/f0fd1a12-bbbb-4113-aaa9-546acb5e286c
# Adding https://cmu.ac.th/th/SDGs/4
# Adding https://cmu.ac.th/th/article/cdacfa11-590a-4f1f-88fb-efd1c088a71f
# Adding https://cmu.ac.th/th/article/cdacfa11-590a-4f1f-88fb-efd1c088a71f
# Adding https://cmu.ac.th/th/SDGs/9
# Adding https://cmu.ac.th/th/article/c91ca2f1-8e20-41fe-93ea-eba427ec44d2
# Adding https://cmu.ac.th/th/article/c91ca2f1-8e20-41fe-93ea-eba427ec44d2
# Adding https://cmu.ac.th/th/article/3043ab0c-1cdf-48a6-a535-faf43b8a8edc
# Adding https://cmu.ac.th/th/article/3043ab0c-1cdf-48a6-a535-faf43b8a8edc
# Adding https://cmu.ac.th/th/article/7a41e20d-098a-47ee-83bf-05212e6b058f
# Adding https://cmu.ac.th/th/article/7a41e20d-098a-47ee-83bf-05212e6b058f
# Adding https://cmu.ac.th/th/article/b3d33d78-f824-4e22-8ba4-da706f3793a7
# Adding https://cmu.ac.th/th/article/b3d33d78-f824-4e22-8ba4-da706f3793a7
# Adding https://cmu.ac.th/th/articlegroup/19536cb6-d89a-4805-b5ab-89bee152e3f9
# Adding https://cmu.ac.th/th/article/0d813fb5-7fb9-4463-978f-5482f172d799
# Adding https://cmu.ac.th/th/article/0d813fb5-7fb9-4463-978f-5482f172d799
# Adding https://cmu.ac.th/th/article/cdacfa11-590a-4f1f-88fb-efd1c088a71f
# Adding https://cmu.ac.th/th/article/cdacfa11-590a-4f1f-88fb-efd1c088a71f
# Adding https://cmu.ac.th/th/SDGs/9
# Adding https://cmu.ac.th/th/article/3043ab0c-1cdf-48a6-a535-faf43b8a8edc
# Adding https://cmu.ac.th/th/article/3043ab0c-1cdf-48a6-a535-faf43b8a8edc
# Adding https://cmu.ac.th/th/article/e81488b4-9dd6-4314-bb98-bb93dde48d44
# Adding https://cmu.ac.th/th/article/e81488b4-9dd6-4314-bb98-bb93dde48d44
# Adding https://cmu.ac.th/th/SDGs/4
# Adding https://cmu.ac.th/th/SDGs/10
# Adding https://cmu.ac.th/th/SDGs/17
# Adding https://cmu.ac.th/th/article/30adc90d-dfbc-441d-b316-ea69de503ae3
# Adding https://cmu.ac.th/th/article/30adc90d-dfbc-441d-b316-ea69de503ae3
# Adding https://cmu.ac.th/th/article/7a41e20d-098a-47ee-83bf-05212e6b058f
# Adding https://cmu.ac.th/th/article/7a41e20d-098a-47ee-83bf-05212e6b058f
# Adding https://cmu.ac.th/th/article/1d77b40b-a500-4a51-b6d9-f6675c454677
# Adding https://cmu.ac.th/th/article/1d77b40b-a500-4a51-b6d9-f6675c454677
# Adding https://cmu.ac.th/th/SDGs/9
# Adding https://cmu.ac.th/th/article/3f8160a1-f46f-4899-a519-65e3dbdf692d
# Adding https://cmu.ac.th/th/article/3f8160a1-f46f-4899-a519-65e3dbdf692d
# Adding https://cmu.ac.th/th/article/22ab0588-d5e1-41ea-acd9-cec0ccc18346
# Adding https://cmu.ac.th/th/article/22ab0588-d5e1-41ea-acd9-cec0ccc18346
# Adding https://cmu.ac.th/th/articlegroup/c902f832-5354-4579-83da-1ec08a468e68
# Adding https://cmu.ac.th/th/article/197a2618-e653-4df8-9649-5cc6548466aa
# Adding https://cmu.ac.th/th/article/197a2618-e653-4df8-9649-5cc6548466aa
# Adding https://cmu.ac.th/th/SDGs/17
# Adding https://cmu.ac.th/th/article/f8128cb2-e1b6-4180-a762-1fdd379d956a
# Adding https://cmu.ac.th/th/article/f8128cb2-e1b6-4180-a762-1fdd379d956a
# Adding https://cmu.ac.th/th/SDGs/17
# Adding https://cmu.ac.th/th/article/ddc9cfb7-4b81-4c55-af5b-98aa60d9d77d
# Adding https://cmu.ac.th/th/article/ddc9cfb7-4b81-4c55-af5b-98aa60d9d77d
# Adding https://cmu.ac.th/th/SDGs/17
# Adding https://cmu.ac.th/th/article/7cfabd7c-8d84-44c2-a4e7-ee1ac313a024
# Adding https://cmu.ac.th/th/article/7cfabd7c-8d84-44c2-a4e7-ee1ac313a024
# Adding https://cmu.ac.th/th/article/498cbb95-44d0-454c-9588-bf8567820eaf
# Adding https://cmu.ac.th/th/article/498cbb95-44d0-454c-9588-bf8567820eaf
# Adding https://cmu.ac.th/th/article/d775563c-7cee-4fcc-ab4e-292e4f680e9f
# Adding https://cmu.ac.th/th/article/d775563c-7cee-4fcc-ab4e-292e4f680e9f
# Adding https://cmu.ac.th/th/article/e985a08d-bf4e-461e-b379-a768f2c3bb1f
# Adding https://cmu.ac.th/th/article/e985a08d-bf4e-461e-b379-a768f2c3bb1f
# Adding https://cmu.ac.th/th/article/75bb4817-2bbe-419c-a28b-63970d359128
# Adding https://cmu.ac.th/th/article/75bb4817-2bbe-419c-a28b-63970d359128
# Adding https://cmu.ac.th/th/article/0204288e-707e-4ad9-9dbd-80a4efc37bf6
# Adding https://cmu.ac.th/th/article/0204288e-707e-4ad9-9dbd-80a4efc37bf6
# Adding https://cmu.ac.th/th/articlegroup/35e916ed-0f06-45fe-9b09-2932cbb21780
# Adding https://cmu.ac.th/th/article/cd701e66-0341-402c-8ae1-44227454cbd9
# Adding https://cmu.ac.th/th/article/cd701e66-0341-402c-8ae1-44227454cbd9
# Adding https://cmu.ac.th/th/article/7fe7f59f-bff6-4eb4-a7a1-ad59de77f419
# Adding https://cmu.ac.th/th/article/7fe7f59f-bff6-4eb4-a7a1-ad59de77f419
# Adding https://cmu.ac.th/th/article/8cc7d502-535b-4c00-8315-c04042508939
# Adding https://cmu.ac.th/th/article/8cc7d502-535b-4c00-8315-c04042508939
# Adding https://cmu.ac.th/th/article/d2f0cd04-0bd3-46be-97b2-fc6e93d1b195
# Adding https://cmu.ac.th/th/article/d2f0cd04-0bd3-46be-97b2-fc6e93d1b195
# Adding https://cmu.ac.th/th/SDGs/17
# Adding https://cmu.ac.th/th/article/d39862d1-3de5-4394-b853-2bce9f174775
# Adding https://cmu.ac.th/th/article/d39862d1-3de5-4394-b853-2bce9f174775
# Adding https://cmu.ac.th/th/article/b3186717-d9d6-4eb9-b4f6-e72a73867663
# Adding https://cmu.ac.th/th/article/b3186717-d9d6-4eb9-b4f6-e72a73867663
# Adding https://cmu.ac.th/th/article/8558c6c7-2ba4-4225-8ab9-36d7a11a380c
# Adding https://cmu.ac.th/th/article/8558c6c7-2ba4-4225-8ab9-36d7a11a380c
# Adding https://cmu.ac.th/th/article/adc3ed55-7c40-466e-9eac-d8cebd4c71ae
# Adding https://cmu.ac.th/th/article/adc3ed55-7c40-466e-9eac-d8cebd4c71ae
# Adding https://cmu.ac.th/th/article/32e738c8-3381-4c2a-8fb8-a3e5849a4674
# Adding https://cmu.ac.th/th/article/32e738c8-3381-4c2a-8fb8-a3e5849a4674
# Adding https://cmu.ac.th/th/articlegroup/726e7707-60ca-497f-aff9-077a4f380b5d
# Adding https://cmu.ac.th/th/article/1011a493-d6a5-4642-8b21-77b75da4f298
# Adding https://cmu.ac.th/th/article/1011a493-d6a5-4642-8b21-77b75da4f298
# Adding https://cmu.ac.th/th/article/ddb8c326-5d0b-484d-8776-200508ec51fa
# Adding https://cmu.ac.th/th/article/ddb8c326-5d0b-484d-8776-200508ec51fa
# Adding https://cmu.ac.th/th/SDGs/8
# Adding https://cmu.ac.th/th/article/d9660553-f6e6-42e5-b82f-ae5bec651a93
# Adding https://cmu.ac.th/th/article/d9660553-f6e6-42e5-b82f-ae5bec651a93
# Adding https://cmu.ac.th/th/article/9fa439f0-9de3-4e9f-b5c7-0e7fe7493ac4
# Adding https://cmu.ac.th/th/article/9fa439f0-9de3-4e9f-b5c7-0e7fe7493ac4
# Adding https://cmu.ac.th/th/article/a8a1ff5d-1dc0-4600-9e19-5a08f873e0c7
# Adding https://cmu.ac.th/th/article/a8a1ff5d-1dc0-4600-9e19-5a08f873e0c7
# Adding https://cmu.ac.th/th/SDGs/8
# Adding https://cmu.ac.th/th/article/220c71b2-894a-4a3b-bc5a-d10e6e53efed
# Adding https://cmu.ac.th/th/article/220c71b2-894a-4a3b-bc5a-d10e6e53efed
# Adding https://cmu.ac.th/th/SDGs/8
# Adding https://cmu.ac.th/th/article/ee613387-acfb-40be-9116-61075272d960
# Adding https://cmu.ac.th/th/article/ee613387-acfb-40be-9116-61075272d960
# Adding https://cmu.ac.th/th/SDGs/8
# Adding https://cmu.ac.th/th/article/f6ca1a38-a8ac-4719-adbd-ac28985752ff
# Adding https://cmu.ac.th/th/article/f6ca1a38-a8ac-4719-adbd-ac28985752ff
# Adding https://cmu.ac.th/th/SDGs/8
# Adding https://cmu.ac.th/th/article/e6e7cc52-21a0-4fe3-89e6-bc8489f87ef0
# Adding https://cmu.ac.th/th/article/e6e7cc52-21a0-4fe3-89e6-bc8489f87ef0
# Adding https://cmu.ac.th/th/Procurement/
# Adding https://cmu.ac.th/th/articlegroup/900283bc-6244-4446-b250-9073705af3f3
# Adding https://cmu.ac.th/th/article/560ad746-3daa-4d12-b3c9-6505e83b14b3
# Adding https://cmu.ac.th/th/article/560ad746-3daa-4d12-b3c9-6505e83b14b3
# Adding https://cmu.ac.th/th/article/cac868ae-4cd0-44cf-a96d-93c84cb74e0b
# Adding https://cmu.ac.th/th/article/cac868ae-4cd0-44cf-a96d-93c84cb74e0b
# Adding https://cmu.ac.th/th/article/7937e981-57de-4929-ae7c-271d7732cdf1
# Adding https://cmu.ac.th/th/article/7937e981-57de-4929-ae7c-271d7732cdf1
# Adding https://cmu.ac.th/th/article/e02f0385-d8cd-4923-8ea2-a093ffdd73fd
# Adding https://cmu.ac.th/th/article/e02f0385-d8cd-4923-8ea2-a093ffdd73fd
# Adding https://cmu.ac.th/th/articlegroup/b27b632e-1cc2-4b88-9236-f30320ad47ee
# Adding https://cmu.ac.th/CMUArticle/ArticleDownload.aspx?id=74f45331-aae3-4142-bea1-12356088513f
# Adding https://cmu.ac.th/CMUArticle/ArticleDownload.aspx?id=74f45331-aae3-4142-bea1-12356088513f
# Adding https://cmu.ac.th/CMUArticle/ArticleDownload.aspx?id=ff293310-3c00-47b3-94f7-2aa380601774
# Adding https://cmu.ac.th/CMUArticle/ArticleDownload.aspx?id=ff293310-3c00-47b3-94f7-2aa380601774
# Adding https://cmu.ac.th/CMUArticle/ArticleDownload.aspx?id=4a805819-efcf-4291-b7ce-2686a5c772d6
# Adding https://cmu.ac.th/CMUArticle/ArticleDownload.aspx?id=4a805819-efcf-4291-b7ce-2686a5c772d6
# Adding https://cmu.ac.th/CMUArticle/ArticleDownload.aspx?id=8a2024fe-e37c-4ed1-8f3e-0f1654a60ade
# Adding https://cmu.ac.th/CMUArticle/ArticleDownload.aspx?id=8a2024fe-e37c-4ed1-8f3e-0f1654a60ade
# Adding https://cmu.ac.th/CMUArticle/ArticleDownload.aspx?id=960ca125-7253-4982-a01f-461175221e79
# Adding https://cmu.ac.th/CMUArticle/ArticleDownload.aspx?id=960ca125-7253-4982-a01f-461175221e79
# Adding https://cmu.ac.th/CMUArticle/ArticleDownload.aspx?id=bace3d0b-c2ed-46f9-9d6a-d0a5f560a45a
# Adding https://cmu.ac.th/CMUArticle/ArticleDownload.aspx?id=bace3d0b-c2ed-46f9-9d6a-d0a5f560a45a
# Adding https://cmu.ac.th/CMUArticle/ArticleDownload.aspx?id=155c7f9d-c35d-4f1b-b769-c7794817540a
# Adding https://cmu.ac.th/CMUArticle/ArticleDownload.aspx?id=155c7f9d-c35d-4f1b-b769-c7794817540a
# Adding https://cmu.ac.th/CMUArticle/ArticleDownload.aspx?id=d8030fae-dfd8-4d21-b72c-29c6e5004464
# Adding https://cmu.ac.th/CMUArticle/ArticleDownload.aspx?id=d8030fae-dfd8-4d21-b72c-29c6e5004464
# Adding https://itas.nacc.go.th/go/eit/bvwzh7
# Adding https://itas.nacc.go.th/go/eit/bvwzh7
# Adding https://www.facebook.com/r.php
# Adding https://www.facebook.com/privacy/policy/
# Adding https://www.facebook.com/legal/terms/
# Adding https://www.facebook.com/policies/cookies/
# Adding https://www.youtube.com/about/
# Adding https://www.youtube.com/about/press/
# Adding https://www.youtube.com/about/copyright/
# Adding https://cmu.ac.th/t/contact_us/
# Adding https://www.youtube.com/creators/
# Adding https://www.youtube.com/ads/
# Adding https://developers.google.com/youtube
# Adding https://cmu.ac.th/t/terms
# Adding https://cmu.ac.th/t/privacy
# Adding https://www.youtube.com/about/policies/
# Adding https://www.youtube.com/howyoutubeworks?utm_campaign=ytgen&utm_source=ythp&utm_medium=LeftNav&utm_content=txt&u=https%3A%2F%2Fwww.youtube.com%2Fhowyoutubeworks%3Futm_source%3Dythp%26utm_medium%3DLeftNav%26utm_campaign%3Dytgen
# Adding https://cmu.ac.th/new
# {'https://cmu.ac.th/th/article/0d813fb5-7fb9-4463-978f-5482f172d799', 'https://cmu.ac.th/pharmacy/aboutus/head', 'https://planning.oou.cmu.ac.th/?cat=36', 'https://cmu.ac.th/th/articlegroup/726e7707-60ca-497f-aff9-077a4f380b5d', 'https://cmu.ac.th/th/60years/article/860af491-5555-49d0-81c2-ec290269c90d', 'https://council.cmu.ac.th/th/members-of-cmu-council/', 'https://cmu.ac.th/th/article/22ab0588-d5e1-41ea-acd9-cec0ccc18346', 'http://www.sys.oop.cmu.ac.th/', 'https://cmu.ac.th/th/faculty/mass_communication/aboutus', 'https://council.cmu.ac.th/th/', 'https://cmu.ac.th/th/article/7cfabd7c-8d84-44c2-a4e7-ee1ac313a024', "javascript:__doPostBack('ctl00$cphPageContent$wucArticleGroup1$lbtnNext','')", 'https://cmu.ac.th/th/privacy', 'https://cmu.ac.th/th/articlegroup/21c227c8-b12e-494b-b37b-ca8458ab863e', 'https://www.youtube.com/howyoutubeworks?utm_campaign=ytgen&utm_source=ythp&utm_medium=LeftNav&utm_content=txt&u=https%3A%2F%2Fwww.youtube.com%2Fhowyoutubeworks%3Futm_source%3Dythp%26utm_medium%3DLeftNav%26utm_campaign%3Dytgen', 'https://cmu.ac.th/CMUArticle/ArticleDownload.aspx?id=960ca125-7253-4982-a01f-461175221e79', 'https://cmu.ac.th/th/60years/article/c3f272d7-2c38-44e6-88ca-bf19596f6d40', 'https://cmu.ac.th/th/60years/article/0fe86d7a-7ce0-4b9d-8fff-0caa037d44b9', 'https://shop.cmu.ac.th/', 'https://mis.cmu.ac.th/TQF/TQF2/CurriculumPublicList.aspx', 'https://cmu.ac.th/political_science_and_public_administration/aboutus/head', 'https://cmu.ac.th/science/aboutus/head', 'https://cmu.ac.th/th/60years/article/7d7325f9-0019-4d81-826a-7abec3c0f6a2', 'https://www.sys.oop.cmu.ac.th', 'https://cmu.ac.th/th/60years', 'https://cmu.ac.th/th/article/9fa439f0-9de3-4e9f-b5c7-0e7fe7493ac4', 'https://cmu.ac.th/th/content/F0917C78-2125-4FFD-AF68-BE9E4F5E0D36', 'https://cmu.ac.th/th/60years/article/eae624c8-67b6-495a-9c9a-89422b9de951', 'https://policy13.cmu.ac.th', 'https://planning.oou.cmu.ac.th/?page_id=4274', 'https://www.cmu.ac.th/th/60years', 'https://cmu.ac.th/th/article/cd701e66-0341-402c-8ae1-44227454cbd9', 'https://cmu.ac.th/faculty', 'https://cmu.ac.th/CMUArticle/ArticleDownload.aspx?id=ff293310-3c00-47b3-94f7-2aa380601774', 'https://cmu.ac.th/th/article/220c71b2-894a-4a3b-bc5a-d10e6e53efed', 'https://cmu.ac.th/th/articlegroup/02b0be9c-5700-4119-8b05-00e4efcb97e7', 'https://cmu.ac.th/th/60years/article/0e3b896b-b1e8-489f-92fc-8a4454f48df9', 'https://cmu.ac.th/th/60years/articlegroup/059f5f5d-b062-4370-83ee-fbc7d0a68e00', 'https://council.cmu.ac.th/th/ita/', 'https://cmu.ac.th/university/adminstrative_offices', 'https://cmu.ac.th/course', 'https://cmu.ac.th/th/60years/article/ecdf8ffa-5c0b-4a5c-ad59-56f73fc30693', 'https://cmu.ac.th/th/articlegroup/35e916ed-0f06-45fe-9b09-2932cbb21780', 'https://cmu.ac.th/th/article/d775563c-7cee-4fcc-ab4e-292e4f680e9f', 'https://cmu.ac.th/th/60years/article/1d872472-2c06-42c3-88be-a865c888f60d', 'https://cmu.ac.th/content/7F64EE14-922A-41B0-B247-E5DD81957E01', 'https://planning.oou.cmu.ac.th/?page_id=3875', 'https://cmu.ac.th/th/faculty/science/aboutus', 'https://cmu.ac.th/content/4EEE10D2-E793-4E55-8D67-400C510F98FE', 'https://planning.oou.cmu.ac.th/?cat=38', 'https://planning.oou.cmu.ac.th/?page_id=3475', 'https://cmu.ac.th/th/faculty/level/bachelor', 'https://cmu.ac.th/th/content/425815A0-90AB-4F39-9DA9-8D5DEA9CDBED', 'https://cmu.ac.th/#top', 'https://e-planning.mis.cmu.ac.th', 'https://e-planning.mis.cmu.ac.th/', 'https://www.sys.oop.cmu.ac.th/meetingroom/signups/login', 'https://cmu.ac.th/#content', 'https://cmu.ac.th/th/article/b3186717-d9d6-4eb9-b4f6-e72a73867663', 'https://cmu.ac.th/th/60years/article/142950ad-3870-4d85-a785-8f3bb3659214', 'https://www.youtube.com/ads/', 'https://www.facebook.com/privacy/policy/', 'https://cmu.ac.th/th/faculty/course', 'https://cmu.ac.th/cmu/history', 'https://cmu.ac.th/level/master_bachelor', 'https://cmu.ac.th/th/article/32e738c8-3381-4c2a-8fb8-a3e5849a4674', 'https://cmu.ac.th/Content/University/CMUPhoneBook.pdf', 'https://cmu.ac.th/choose.aspx?lang=en',  ...

# %% [markdown]
# ### Page 35

# %% [markdown]
# ### PreProcess

# %%
from nltk import word_tokenize
import re


def preProcess(s):
    s = s.lower()
    s = re.sub(r'[^A-Za-z]', ' ', s)
    s = re.sub(r'\s+', ' ', s)
    s = word_tokenize(s)
    return ' '.join(s)

# %%
import os
import pickle
import json
from pathlib import Path
import pandas as pd
from sklearn.feature_extraction.text import TfidfVectorizer
from nltk.corpus import stopwords
from rank_bm25 import BM25

class Indexer:
    def __init__(self, is_reset=False):
        self.crawled_folder = Path(os.path.abspath('')).parent / 'crawled/'
        self.stored_file = 'src/resource/manual_indexer.pkl'

        if not is_reset and os.path.isfile(self.stored_file):
            with open(self.stored_file, 'rb') as f:
                cached_dict = pickle.load(f)
                self.__dict__.update(cached_dict)
        else:
            self.run_indexer()

    def run_indexer(self):
        documents = []
        for file in os.listdir(self.crawled_folder):
            if file.endswith(".txt"):
                with open(os.path.join(self.crawled_folder, file)) as f:
                    j = json.load(f)
                    documents.append(j)

        self.documents = pd.DataFrame(documents)

        tfidf_vectorizer = TfidfVectorizer(preprocessor=preProcess, stop_words=stopwords.words('english'))
        self.bm25 = BM25(tfidf_vectorizer)
        self.bm25.fit(self.documents.apply(lambda s: ' '.join(s[['title', 'text']]), axis=1))

        with open(self.stored_file, 'wb') as f:
            pickle.dump(self.__dict__, f)

# %%
from sklearn.feature_extraction.text import TfidfVectorizer
import numpy as np
from scipy import sparse
import pandas as pd
import json
import os
import pickle
from pathlib import Path
from tabulate import tabulate
import re

# %%
class BM25:
    def __init__(self, b=0.75, k1=1.6):
        """
        BM25 implementation using TfidfVectorizer for vectorization.
        """
        self.b = b
        self.k1 = k1
        self.vectorizer = TfidfVectorizer(lowercase=True, stop_words='english', use_idf=True)

    def fit(self, X):
        """
        Fit the model with a list of documents X.
        """
        self.vectorizer.fit(X)
        self.y = self.vectorizer.transform(X)
        self.avdl = self.y.sum(axis=1).mean()  # Average document length

    def transform(self, q):
        """
        Calculate BM25 scores between query q and documents X.
        """
        b, k1, avdl = self.b, self.k1, self.avdl

        # Apply CountVectorizer
        len_y = self.y.sum(axis=1).A1  # Length of each document
        q_vector = self.vectorizer.transform([q])  # Vectorize query
        assert sparse.isspmatrix_csr(q_vector)

        # Convert to csc for better column slicing
        y_csc = self.y.tocsc()[:, q_vector.indices]
        denom = y_csc + (k1 * (1 - b + b * len_y / avdl))[:, None]
        idf = self.vectorizer.idf_[None, q_vector.indices] - 1.0
        numer = y_csc.multiply(np.broadcast_to(idf, y_csc.shape)) * (k1 + 1)
        return (numer / denom).sum(axis=1).A1

# %%
class WebIndexer:
    def __init__(self, is_reset=False):
        """
        Initialize the WebIndexer and load preprocessed data if exists.
        """
        self.crawled_folder = Path(Path().absolute()).parent / "crawled/"
        self.stored_file = 'src/resource/manual_indexer.pkl'

        # Load the cached index if it exists and is_reset is False
        if not is_reset and os.path.isfile(self.stored_file):
            with open(self.stored_file, "rb") as f:
                cached_dict = pickle.load(f)
            self.__dict__.update(cached_dict)
        else:
            self.run_indexer()

    @staticmethod
    def preprocess_text(text):
        """
        Preprocess text by lowercasing, removing punctuation, and cleaning spaces.
        """
        # Lowercase text
        text = text.lower()
        # Remove punctuation and special characters
        text = re.sub(r'[^\w\s]', '', text)
        # Remove extra spaces
        text = re.sub(r'\s+', ' ', text).strip()
        return text

    def run_indexer(self):
        """
        Load documents from crawled folder, preprocess, and index them.
        """
        documents = []

        # Load all .txt files from crawled folder
        for file in os.listdir(self.crawled_folder):
            if file.endswith(".txt"):
                file_path = os.path.join(self.crawled_folder, file)

                # Read the file with UTF-8 encoding and handle errors
                with open(file_path, "r", encoding="utf-8", errors="replace") as f:
                    try:
                        j = json.load(f)
                        if 'title' in j and 'text' in j:
                            # Preprocess title and text
                            j['title'] = self.preprocess_text(j['title'])
                            j['text'] = self.preprocess_text(j['text'])
                            documents.append(j)
                        else:
                            print(f"Skipped file {file}: Missing 'title' or 'text'")
                    except json.JSONDecodeError as e:
                        print(f"Error decoding JSON in {file}: {e}")
                    except Exception as e:
                        print(f"Error reading {file}: {e}")

        if not documents:
            raise ValueError("No valid documents found. Ensure crawled/ folder contains valid .txt files.")

        # Preprocess and create BM25 index
        self.documents = pd.DataFrame.from_dict(documents)
        corpus = self.documents.apply(lambda s: ' '.join(s[['title', 'text']]), axis=1).tolist()

        if not corpus:
            raise ValueError("Corpus is empty. Ensure documents contain 'title' and 'text' fields.")

        # Initialize BM25 and fit the corpus
        self.bm25 = BM25()
        self.bm25.fit(corpus)

        # Ensure directory exists before saving
        os.makedirs(os.path.dirname(self.stored_file), exist_ok=True)

        # Save the final processed data
        with open(self.stored_file, "wb") as f:
            pickle.dump(self.__dict__, f)

    def search_query(self, query, top_n=5):
        """
        Perform a search query on the indexed data.
        """
        # Preprocess query
        query = self.preprocess_text(query)
        query_scores = self.bm25.transform(query)

        if not any(query_scores):
            raise ValueError("No documents matched the query. Check the query or indexed data.")

        self.documents["score"] = query_scores
        results = self.documents.nlargest(top_n, "score")[["url", "title", "text", "score"]]

        return results

# %%
if __name__ == "__main__":
    indexer = WebIndexer(is_reset=False)

    query = "school"
    try:
        results = indexer.search_query(query, top_n=5)
        print(tabulate(results, headers="keys", tablefmt="grid"))
    except ValueError as e:
        print(f"Error: {e}")
# Out:
# +-----+---------------------------------------------+----------------------+-----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+----------+
# |     | url                                         | title                | text                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                              |    score |
# +=====+=============================================+======================+===================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================+==========+
# |  17 | https://cmu.ac.th/th/faculty/course         | คณะ มหาวทยาลยเชยงใหม | cmu หลกสตร แยกตามคณะ คนหาหลกสตร ปรญญาตร ปรญญาโท ปรญญาเอก หลกสตรอนๆ การศกษา การรบสมครระดบปรญญาตร การรบสมครระดบบณฑตศกษา การรบสมครหลกสตรนานาชาต ทนอธการบดมหาวทยาลยเชยงใหม คณะและหนวยงาน คณะ หนวยงาน สวนงานอนๆ th en cn th en cn หลกสตร แยกตามคณะ คนหาหลกสตร ปรญญาตร ปรญญาโท ปรญญาเอก หลกสตรอนๆ การศกษา การรบสมครระดบปรญญาตร การรบสมครระดบบณฑตศกษา การรบสมครหลกสตรนานาชาต ทนอธการบดมหาวทยาลยเชยงใหม คณะและหนวยงาน คณะ หนวยงาน สวนงานอนๆ ขาวสาร ขาวงานวจยและนวตกรรม ขาวเดน ขาวบคคลเดน รางวลและความภาคภมใจ ประชมสมมนากจกรรมของมหาวทยาลย ภาพขาวผบรหาร ขาวรบสมครงาน ขาวจดซอจดจาง ปฏทนกจกรรม covid19 และ pm25 เกยวกบ มช ประวตความเปนมา 60 ป มช ปณธานวสยทศนพนธกจคานยมและวฒนธรรมองคกร อำนาจหนาท สญลกษณมหาวทยาลย เกยวกบมช ขอมลสาธารณะ cmu 360 องศา sdgs โครงสรางองคกรและการบรหารมหาวทยาลยเชยงใหม แผนพฒนาการศกษามช ระยะ 5 ป คณะกรรมการสภามหาวทยาลย คณะผบรหารมหาวทยาลย ผบรหารสวนงาน ผบรหารหนวยงาน สภาพนกงาน download cmu powerpoint template ชองทางการสอบถามขอมล qa นโยบายคมครองขอมลสวนบคคล ตดตอเรา เสนอแนะรองเรยน คณะ หนาแรก คณะ คณะการสอสารมวลชน faculty of mass communication คณะเกษตรศาสตร faculty of agriculture คณะทนตแพทยศาสตร faculty of dentistry คณะเทคนคการแพทย faculty of associated medical sciences คณะนตศาสตร faculty of law คณะบรหารธรกจ chiang mai university business school คณะพยาบาลศาสตร faculty of nursing คณะแพทยศาสตร faculty of medicine คณะเภสชศาสตร faculty of pharmacy คณะมนษยศาสตร faculty of humanities คณะรฐศาสตรและรฐประศาสนศาสตร faculty of political science and public administration คณะวจตรศลป faculty of fine arts คณะวทยาศาสตร faculty of science คณะวศวกรรมศาสตร faculty of engineering คณะศกษาศาสตร faculty of education คณะเศรษฐศาสตร faculty of economics คณะสถาปตยกรรมศาสตร faculty of architecture คณะสงคมศาสตร faculty of social sciences คณะสตวแพทยศาสตร faculty of veterinary medicine คณะสาธารณสขศาสตร faculty of public health คณะอตสาหกรรมเกษตร faculty of agroindustry วทยาลยนานาชาตนวตกรรมดจทล international college of digital innovation วทยาลยพหวทยาการและสหวทยาการ multidisciplinary and interdisciplinary school วทยาลยศลปะ สอ และเทคโนโลย college of art media and technology สถาบนนโยบายสาธารณะ school of public policy chiang mai university สถาบนวศวกรรมชวการแพทย biomedical engineering institute copyright 2019 chiang mai university all rights reserved by information technology service center ตดตอมหาวทยาลย มหาวทยาลยเชยงใหม 239 ถนนหวยแกว ตสเทพ อเมอง จเชยงใหม 50200 โทรศพท 66 5394 1300 โทรสาร 66 5321 7143 อเมล contactscmuacth ศนยสอสารองคกรและนกศกษาเกาสมพนธ โทรศพท 66 5394 3333 66 5394 4444 โทรสาร 66 5394 4900 อเมล ccarccmuacth กองวเทศสมพนธ สำนกงานมหาวทยาลย บรการสำคญ สมดโทรศพทมหาวทยาลยเชยงใหม แผนทมหาวทยาลยเชยงใหม การบรจาค cmu mail cmu mis สำหรบเจาหนาท เยยมชมมหาวทยาลยเชยงใหม cmu 360 องศา ชองทางสอสาร website httpswwwcmuacth                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                             | 0.388017 |
# +-----+---------------------------------------------+----------------------+-----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+----------+
# |  25 | https://cmu.ac.th/th/faculty/aboutus        | คณะ มหาวทยาลยเชยงใหม | cmu หลกสตร แยกตามคณะ คนหาหลกสตร ปรญญาตร ปรญญาโท ปรญญาเอก หลกสตรอนๆ การศกษา การรบสมครระดบปรญญาตร การรบสมครระดบบณฑตศกษา การรบสมครหลกสตรนานาชาต ทนอธการบดมหาวทยาลยเชยงใหม คณะและหนวยงาน คณะ หนวยงาน สวนงานอนๆ th en cn th en cn หลกสตร แยกตามคณะ คนหาหลกสตร ปรญญาตร ปรญญาโท ปรญญาเอก หลกสตรอนๆ การศกษา การรบสมครระดบปรญญาตร การรบสมครระดบบณฑตศกษา การรบสมครหลกสตรนานาชาต ทนอธการบดมหาวทยาลยเชยงใหม คณะและหนวยงาน คณะ หนวยงาน สวนงานอนๆ ขาวสาร ขาวงานวจยและนวตกรรม ขาวเดน ขาวบคคลเดน รางวลและความภาคภมใจ ประชมสมมนากจกรรมของมหาวทยาลย ภาพขาวผบรหาร ขาวรบสมครงาน ขาวจดซอจดจาง ปฏทนกจกรรม covid19 และ pm25 เกยวกบ มช ประวตความเปนมา 60 ป มช ปณธานวสยทศนพนธกจคานยมและวฒนธรรมองคกร อำนาจหนาท สญลกษณมหาวทยาลย เกยวกบมช ขอมลสาธารณะ cmu 360 องศา sdgs โครงสรางองคกรและการบรหารมหาวทยาลยเชยงใหม แผนพฒนาการศกษามช ระยะ 5 ป คณะกรรมการสภามหาวทยาลย คณะผบรหารมหาวทยาลย ผบรหารสวนงาน ผบรหารหนวยงาน สภาพนกงาน download cmu powerpoint template ชองทางการสอบถามขอมล qa นโยบายคมครองขอมลสวนบคคล ตดตอเรา เสนอแนะรองเรยน คณะ หนาแรก คณะ คณะการสอสารมวลชน faculty of mass communication คณะเกษตรศาสตร faculty of agriculture คณะทนตแพทยศาสตร faculty of dentistry คณะเทคนคการแพทย faculty of associated medical sciences คณะนตศาสตร faculty of law คณะบรหารธรกจ chiang mai university business school คณะพยาบาลศาสตร faculty of nursing คณะแพทยศาสตร faculty of medicine คณะเภสชศาสตร faculty of pharmacy คณะมนษยศาสตร faculty of humanities คณะรฐศาสตรและรฐประศาสนศาสตร faculty of political science and public administration คณะวจตรศลป faculty of fine arts คณะวทยาศาสตร faculty of science คณะวศวกรรมศาสตร faculty of engineering คณะศกษาศาสตร faculty of education คณะเศรษฐศาสตร faculty of economics คณะสถาปตยกรรมศาสตร faculty of architecture คณะสงคมศาสตร faculty of social sciences คณะสตวแพทยศาสตร faculty of veterinary medicine คณะสาธารณสขศาสตร faculty of public health คณะอตสาหกรรมเกษตร faculty of agroindustry วทยาลยนานาชาตนวตกรรมดจทล international college of digital innovation วทยาลยพหวทยาการและสหวทยาการ multidisciplinary and interdisciplinary school วทยาลยศลปะ สอ และเทคโนโลย college of art media and technology สถาบนนโยบายสาธารณะ school of public policy chiang mai university สถาบนวศวกรรมชวการแพทย biomedical engineering institute copyright 2019 chiang mai university all rights reserved by information technology service center ตดตอมหาวทยาลย มหาวทยาลยเชยงใหม 239 ถนนหวยแกว ตสเทพ อเมอง จเชยงใหม 50200 โทรศพท 66 5394 1300 โทรสาร 66 5321 7143 อเมล contactscmuacth ศนยสอสารองคกรและนกศกษาเกาสมพนธ โทรศพท 66 5394 3333 66 5394 4444 โทรสาร 66 5394 4900 อเมล ccarccmuacth กองวเทศสมพนธ สำนกงานมหาวทยาลย บรการสำคญ สมดโทรศพทมหาวทยาลยเชยงใหม แผนทมหาวทยาลยเชยงใหม การบรจาค cmu mail cmu mis สำหรบเจาหนาท เยยมชมมหาวทยาลยเชยงใหม cmu 360 องศา ชองทางสอสาร website httpswwwcmuacth                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                             | 0.388017 |
# +-----+---------------------------------------------+----------------------+-----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+----------+
# | 172 | https://www.cmu.ac.th/th/faculty/aboutus    | คณะ มหาวทยาลยเชยงใหม | cmu หลกสตร แยกตามคณะ คนหาหลกสตร ปรญญาตร ปรญญาโท ปรญญาเอก หลกสตรอนๆ การศกษา การรบสมครระดบปรญญาตร การรบสมครระดบบณฑตศกษา การรบสมครหลกสตรนานาชาต ทนอธการบดมหาวทยาลยเชยงใหม คณะและหนวยงาน คณะ หนวยงาน สวนงานอนๆ th en cn th en cn หลกสตร แยกตามคณะ คนหาหลกสตร ปรญญาตร ปรญญาโท ปรญญาเอก หลกสตรอนๆ การศกษา การรบสมครระดบปรญญาตร การรบสมครระดบบณฑตศกษา การรบสมครหลกสตรนานาชาต ทนอธการบดมหาวทยาลยเชยงใหม คณะและหนวยงาน คณะ หนวยงาน สวนงานอนๆ ขาวสาร ขาวงานวจยและนวตกรรม ขาวเดน ขาวบคคลเดน รางวลและความภาคภมใจ ประชมสมมนากจกรรมของมหาวทยาลย ภาพขาวผบรหาร ขาวรบสมครงาน ขาวจดซอจดจาง ปฏทนกจกรรม covid19 และ pm25 เกยวกบ มช ประวตความเปนมา 60 ป มช ปณธานวสยทศนพนธกจคานยมและวฒนธรรมองคกร อำนาจหนาท สญลกษณมหาวทยาลย เกยวกบมช ขอมลสาธารณะ cmu 360 องศา sdgs โครงสรางองคกรและการบรหารมหาวทยาลยเชยงใหม แผนพฒนาการศกษามช ระยะ 5 ป คณะกรรมการสภามหาวทยาลย คณะผบรหารมหาวทยาลย ผบรหารสวนงาน ผบรหารหนวยงาน สภาพนกงาน download cmu powerpoint template ชองทางการสอบถามขอมล qa นโยบายคมครองขอมลสวนบคคล ตดตอเรา เสนอแนะรองเรยน คณะ หนาแรก คณะ คณะการสอสารมวลชน faculty of mass communication คณะเกษตรศาสตร faculty of agriculture คณะทนตแพทยศาสตร faculty of dentistry คณะเทคนคการแพทย faculty of associated medical sciences คณะนตศาสตร faculty of law คณะบรหารธรกจ chiang mai university business school คณะพยาบาลศาสตร faculty of nursing คณะแพทยศาสตร faculty of medicine คณะเภสชศาสตร faculty of pharmacy คณะมนษยศาสตร faculty of humanities คณะรฐศาสตรและรฐประศาสนศาสตร faculty of political science and public administration คณะวจตรศลป faculty of fine arts คณะวทยาศาสตร faculty of science คณะวศวกรรมศาสตร faculty of engineering คณะศกษาศาสตร faculty of education คณะเศรษฐศาสตร faculty of economics คณะสถาปตยกรรมศาสตร faculty of architecture คณะสงคมศาสตร faculty of social sciences คณะสตวแพทยศาสตร faculty of veterinary medicine คณะสาธารณสขศาสตร faculty of public health คณะอตสาหกรรมเกษตร faculty of agroindustry วทยาลยนานาชาตนวตกรรมดจทล international college of digital innovation วทยาลยพหวทยาการและสหวทยาการ multidisciplinary and interdisciplinary school วทยาลยศลปะ สอ และเทคโนโลย college of art media and technology สถาบนนโยบายสาธารณะ school of public policy chiang mai university สถาบนวศวกรรมชวการแพทย biomedical engineering institute copyright 2019 chiang mai university all rights reserved by information technology service center ตดตอมหาวทยาลย มหาวทยาลยเชยงใหม 239 ถนนหวยแกว ตสเทพ อเมอง จเชยงใหม 50200 โทรศพท 66 5394 1300 โทรสาร 66 5321 7143 อเมล contactscmuacth ศนยสอสารองคกรและนกศกษาเกาสมพนธ โทรศพท 66 5394 3333 66 5394 4444 โทรสาร 66 5394 4900 อเมล ccarccmuacth กองวเทศสมพนธ สำนกงานมหาวทยาลย บรการสำคญ สมดโทรศพทมหาวทยาลยเชยงใหม แผนทมหาวทยาลยเชยงใหม การบรจาค cmu mail cmu mis สำหรบเจาหนาท เยยมชมมหาวทยาลยเชยงใหม cmu 360 องศา ชองทางสอสาร website httpswwwcmuacth                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                             | 0.388017 |
# +-----+---------------------------------------------+----------------------+-----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+----------+
# | 203 | https://cmu.ac.th/en/faculty/aboutus        | คณะ มหาวทยาลยเชยงใหม | cmu curricular seperating faculties search for curriculums bachelors degree masters degree doctoral degree other curriculums studying at cmu application of bachelors degree application for graduate studies application of international program cmu presidential scholarship faculties and departments faculties cmus organizations other division th en cn th en cn curricular seperating faculties search for curriculums bachelors degree masters degree doctoral degree other curriculums studying at cmu application of bachelors degree application for graduate studies application of international program cmu presidential scholarship faculties and departments faculties cmus organizations other division news research and innovation news outstanding news outstanding staff prize and pride conference and seminar executives news job application procurement event calendar covid19 and pm25 about cmu background the 60th anniversary of chiang mai university resolution vision missionvalues and organizational culture authority the universitys logo about cmu open data integrity and transparency assessment oit cmu 360 sustainable development goals organizational structure and administration of chiang mai university education development plan 5 years committee of university council executives deans directors employee council download cmu powerpoint template qa privacy policy contact suggestion faculties home faculties faculty of mass communication faculty of mass communication faculty of agriculture faculty of agriculture faculty of dentistry faculty of dentistry faculty of associated medical sciences faculty of associated medical sciences faculty of law faculty of law chiang mai university business school chiang mai university business school faculty of nursing faculty of nursing faculty of medicine faculty of medicine faculty of pharmacy faculty of pharmacy faculty of humanities faculty of humanities faculty of political science and public administration faculty of political science and public administration faculty of fine arts faculty of fine arts faculty of science faculty of science faculty of engineering faculty of engineering faculty of education faculty of education faculty of economics faculty of economics faculty of architecture faculty of architecture faculty of social sciences faculty of social sciences faculty of veterinary medicine faculty of veterinary medicine faculty of public health faculty of public health faculty of agroindustry faculty of agroindustry international college of digital innovation international college of digital innovation multidisciplinary and interdisciplinary school multidisciplinary and interdisciplinary school college of art media and technology college of art media and technology school of public policy chiang mai university school of public policy chiang mai university biomedical engineering institute biomedical engineering institute copyright 2019 chiang mai university all rights reserved by information technology service center contact chiang mai university 239 huay kaew road muang districtchiang mai thailand 50200 telephone 66 5394 3661 to 5 fax 66 5394 2670 email irdcmucmuacth international relations division office of the university cmu telephone 66 5394 3661 to 5 fax 66 5394 2670 email irdcmucmuacth contact corporate communication and alumni relations center telephone 66 5394 1300 fax 66 5394 4900 email ccarccmuacth services phone book cmu map donation cmu mail cmu mis for staff visit chiang mai university cmu 360 communication website httpswwwcmuacth | 0.360131 |
# +-----+---------------------------------------------+----------------------+-----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+----------+
# | 200 | https://mis.cmu.ac.th/tqf/coursepublic.aspx |                      | กระบวนวชา รายการกระบวนวชา อาจารยผรบผดชอบหลกสตร year 2569 2568 2567 2566 2565 2564 2563 2562 2561 2560 2559 2558 2557 2556 semester 1 2 summer before applying please choose your semester and academic year กรณาเลอกขอมลภาคการศกษาและปการศกษาของนกศกษา กอนใชขอมลทกครง faculty faculty of humanities faculty of education faculty of fine arts faculty of social sciences faculty of science faculty of engineering faculty of medicine faculty of agriculture faculty of dentistry faculty of pharmacy faculty of associated medical sciences faculty of nursing faculty of agroindustry faculty of veterinary medicine faculty of business administration faculty of economics faculty of architecture faculty of mass communication faculty of political science and public administration faculty of law college of arts media and technology biomedical engineering institute multidisciplinary and interdisciplinary school research institute for health sciences school of public policy faculty of public health international college of digital innovation college of marine studies and management แสดงจำนวน 0 รายการ ขอมลกระบวนวชานนำมาจากขอมล course template ไดรบการตรวจสอบแลวจากสำนกพฒนาคณภาพการศกษา และ วทยาลยพหวทยาการและสหวทยาการ cmu mis                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                       | 0.337997 |
# +-----+---------------------------------------------+----------------------+-----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+----------+

# %%
indexer.documents
# Out:
#                                                    url  \
# 0                            https://portal.cmu.ac.th/
# 1                    https://mis.cmu.ac.th/publication
# 2                              https://shop.cmu.ac.th/
# 3    https://mis.cmu.ac.th/TQF/TQF2/CurriculumPubli...
# 4    https://cmu.ac.th/th/content/D7ABB770-4C2B-41E...
# ..                                                 ...
# 216              https://www.facebook.com/cmuofficial/
# 217  https://cmu.ac.th/th/faculty/level/master_bach...
# 218  https://cmu.ac.th/th/60years/article/7d7325f9-...
# 219  https://cmu.ac.th/th/60years/article/84a6fc60-...
# 220                  https://council.cmu.ac.th/th/ita/
#
#                                                  title  \
# 0                                        itsc services
# 1                                            home page
# 2      มลนธพฒนามหาวทยาลยเชยงใหม จำหนายของทระลก 60 ป มช
# 3
# 4      มหาวทยาลยเชยงใหม chiang mai university thailand
# ..                                                 ...
# 216  มหาวทยาลยเชยงใหม chiang mai university chiang mai
# 217    มหาวทยาลยเชยงใหม chiang mai university thailand
# 218  ขาวสาร เชญชมการแสดงขบรองประสานเสยง โดย วง cmu ...
# 219  ขาวสาร รวมฉลอง 60 ป มช ประกวด ภาพแหงความทรงจำ ...
# 220  คณธรรมและความโปรงใสในการดำเนนงานของหนวยงาน ita...
#
#                                                   text  \
# 0    itsc searchtype services search all students s...
# 1    สารสนเทศผลงานทางวชาการ มหาวทยาลยเชยงใหม ปเผยแพ...
# 2    skip to content มลนธพฒนามหาวทยาลยเชยงใหม จำหนา...
# 3    หลกสตร รายการหลกสตร อาจารยผรบผดชอบหลกสตร year ...
# 4    cmu หลกสตร แยกตามคณะ คนหาหลกสตร ปรญญาตร ปรญญาโ...
# ..                                                 ...
# 216
# 217  cmu หลกสตร แยกตามคณะ คนหาหลกสตร ปรญญาตร ปรญญาโ...
# 218  cmu th en cn home about us สารจากอธการ ประวต ม...
# 219  cmu th en cn home about us สารจากอธการ ประวต ม...
# 220  skip to content หนาหลก สภามหาวทยาลย แผนภมโครงส...
#
#                                              url_lists     score
# 0                                                   []  0.000000
# 1                                                   []  0.000000
# 2                                                   []  0.000000
# 3    [https://cmu.ac.th/CurriculumLecturerPublicLis...  0.285078
# 4                                                   []  0.000000
# ..                                                 ...       ...
# 216                                                 []  0.000000
# 217                                                 []  0.148912
# 218                                                 []  0.000000
# 219                                                 []  0.000000
# 220                                                 []  0.000000
#
# [221 rows x 5 columns]

# %%
results = indexer.search_query("itsc")

# %%
results
# Out:
#                                                    url  \
# 0                            https://portal.cmu.ac.th/
# 134                https://mis.cmu.ac.th/CMUBuildings/
# 126                            https://itsc.cmu.ac.th/
# 204                       https://e-council.cmu.ac.th/
# 206  https://oauth.cmu.ac.th/v1/Authorize.aspx?resp...
#
#                                           title  \
# 0                                 itsc services
# 134                         cmu building system
# 126  สำนกบรการเทคโนโลยสารสนเทศ มหาวทยาลยเชยงใหม
# 204        cmu account sign in with cmu account
# 206        cmu account sign in with cmu account
#
#                                                   text     score
# 0    itsc searchtype services search all students s...  1.958642
# 134  cmu building system ระบบสารสนเทศ และ จดการขอมล...  1.810092
# 126  239 huay kaew roadmuang district chiang mai th...  1.516517
# 204  sign in to continue to cmu ecouncil email addr...  1.441180
# 206  sign in to continue to สบคนมตทประชมสภามหาวทยาล...  1.421396

# %% [markdown]
# ### Elasticsearch & python

# %%
from elasticsearch import Elasticsearch

es = Elasticsearch("https://localhost:9200", basic_auth=("elastic", "9L43t2V91jSE8k1Yh5+Q"),ca_certs="../http_ca.crt")
es.info().body
# Out:
# {'name': 'af716ff81605',
#  'cluster_name': 'docker-cluster',
#  'cluster_uuid': 'D_w8te2pR-6RHxuRTFRu9A',
#  'version': {'number': '8.12.2',
#   'build_flavor': 'default',
#   'build_type': 'docker',
#   'build_hash': '48a287ab9497e852de30327444b0809e55d46466',
#   'build_date': '2024-02-19T10:04:32.774273190Z',
#   'build_snapshot': False,
#   'lucene_version': '9.9.2',
#   'minimum_wire_compatibility_version': '7.17.0',
#   'minimum_index_compatibility_version': '7.0.0'},
#  'tagline': 'You Know, for Search'}
